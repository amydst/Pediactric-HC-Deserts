# %%
import pandas as pd

# %%
Path1 = "Doctors_per_code-good.csv"

# %%
df= pd.read_csv(Path1)

# %%
df.head()
# Out:
#    ZIP Code State      City/Town   Primary Specialty  \
# 0     94304    CA      PALO ALTO  PEDIATRIC MEDICINE
# 1     91402    CA  PANORAMA CITY  PEDIATRIC MEDICINE
# 2     92604    CA         IRVINE  PEDIATRIC MEDICINE
# 3     92868    CA         ORANGE  PEDIATRIC MEDICINE
# 4     92868    CA         ORANGE  PEDIATRIC MEDICINE
#
#              All Secondary Specialties Gender  \
# 0                                  NaN      M
# 1                   INFECTIOUS DISEASE      M
# 2                                  NaN      F
# 3  CARDIOVASCULAR DISEASE (CARDIOLOGY)      M
# 4  CARDIOVASCULAR DISEASE (CARDIOLOGY)      M
#
#                                   Facility Name         NPI  \
# 0              LPCH MEDICAL GROUP DIV OF LUCILE  1003829771
# 1  SOUTHERN CALIFORNIA PERMANENTE MEDICAL GROUP  1013128297
# 2               MEMORIALCARE MEDICAL FOUNDATION  1013907377
# 3          CHILDREN'S HOSPITAL OF ORANGE COUNTY  1013912054
# ...

# %%
Path2 = 'kids_per_code.csv'

# %%
df2= pd.read_csv(Path2)

# %%
df2.head()
# Out:
#    ZIP Code  Population Under 18 years (Selected)  Total Population  \
# 0     89010                                    71               461
# 1     89019                                   146              2312
# 2     89060                                  1917             12198
# 3     89061                                   971              7529
# 4     89439                                   192              1639
#
#    Population Under 5 years  Population 5 to 9 years  \
# 0                        20                       28
# 1                        56                       31
# 2                       509                      662
# 3                        69                      411
# 4                        42                      111
#
#    Population 10 to 14 years  Population 15 to 19 years  \
# 0                         23                         10
# 1                         28                         76
# 2                        372                        510
# ...

# %%
Path3 = 'income_per_code.csv'

# %%
df3= pd.read_csv(Path2)

# %%
df3.head()
# Out:
#    ZIP Code  Population Under 18 years (Selected)  Total Population  \
# 0     89010                                    71               461
# 1     89019                                   146              2312
# 2     89060                                  1917             12198
# 3     89061                                   971              7529
# 4     89439                                   192              1639
#
#    Population Under 5 years  Population 5 to 9 years  \
# 0                        20                       28
# 1                        56                       31
# 2                       509                      662
# 3                        69                      411
# 4                        42                      111
#
#    Population 10 to 14 years  Population 15 to 19 years  \
# 0                         23                         10
# 1                         28                         76
# 2                        372                        510
# ...

# %%
Path4 = 'pop_density_per_zip.csv'

# %%
df4= pd.read_csv(Path4)

# %%
df4.head()
# Out:
#    Zipcode Land Area sq meters Water Area sq meters  Land Area sq miles  \
# 0    89060       1,164,029,185               83,993             449.434
# 1    89061         165,855,694               10,631              64.037
# 2    89439          42,115,079              336,966              16.261
# 3    90001           8,495,419                    0               3.280
# 4    90002           7,750,658                    0               2.993
#
#    Water Area sq miles   Latitude     Longitude  Population  \
# 0                0.032  36.391556  −116.0575681     10692.0
# 1                0.004  36.070110  −115.9062487      5537.0
# 2                0.130  39.523352  −119.9903835      1244.0
# 3                0.000  33.973665  −118.2490388     58974.0
# 4                0.000  33.948987  −118.2467796     53402.0
#
#    Population Density per sq mile
# 0                       23.789922
# 1                       86.465637
# 2                       76.502060
# ...

# %%
Path5 = 'poverty_rate_per_zip.csv'

# %%
df5= pd.read_csv(Path5)

# %%
df5.head()
# Out:
#    Zipcode  Population  Per Capita Income  Poverty Count  Poverty Rate  \
# 0    89060     12198.0            31138.0         2183.0     17.896376
# 1    89061      7529.0            33771.0          486.0      6.455041
# 2    89439      1639.0            65281.0           93.0      5.674192
# 3    90001     57652.0            17994.0        12186.0     21.137168
# 4    90002     53108.0            18262.0        12740.0     23.988853
#
#    Insurance coverage status  Coverage Rate
# 0                    11857.0      97.204460
# 1                     7529.0     100.000000
# 2                     1639.0     100.000000
# 3                    57639.0      99.977451
# 4                    53100.0      99.984936

# %%
df_total = pd.merge(df, df2, on='ZIP Code', how='inner')
df_total
# Out:
#      ZIP Code State      City/Town   Primary Specialty  \
# 0       94304    CA      PALO ALTO  PEDIATRIC MEDICINE
# 1       91402    CA  PANORAMA CITY  PEDIATRIC MEDICINE
# 2       92604    CA         IRVINE  PEDIATRIC MEDICINE
# 3       92868    CA         ORANGE  PEDIATRIC MEDICINE
# 4       92868    CA         ORANGE  PEDIATRIC MEDICINE
# ..        ...   ...            ...                 ...
# 532     92868    CA         ORANGE  PEDIATRIC MEDICINE
# 533     90027    CA    LOS ANGELES  PEDIATRIC MEDICINE
# 534     94304    CA      PALO ALTO  PEDIATRIC MEDICINE
# 535     92833    CA      FULLERTON  PEDIATRIC MEDICINE
# 536     90027    CA    LOS ANGELES  PEDIATRIC MEDICINE
#
#                All Secondary Specialties Gender  \
# 0                                    NaN      M
# 1                     INFECTIOUS DISEASE      M
# 2                                    NaN      F
# 3    CARDIOVASCULAR DISEASE (CARDIOLOGY)      M
# 4    CARDIOVASCULAR DISEASE (CARDIOLOGY)      M
# ...

# %%
df_total.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 537 entries, 0 to 536
# Data columns (total 28 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   ZIP Code                                      537 non-null    int64
#  1   State                                         537 non-null    object
#  2   City/Town                                     537 non-null    object
#  3   Primary Specialty                             537 non-null    object
#  4   All Secondary Specialties                     247 non-null    object
#  5   Gender                                        537 non-null    object
#  6   Facility Name                                 496 non-null    object
#  7   NPI                                           537 non-null    int64
#  8   Provider Last Name                            537 non-null    object
# ...

# %%
df_tota = pd.merge(df_total, df3, on='ZIP Code', how='inner')
df_tota
# Out:
#      ZIP Code State      City/Town   Primary Specialty  \
# 0       94304    CA      PALO ALTO  PEDIATRIC MEDICINE
# 1       91402    CA  PANORAMA CITY  PEDIATRIC MEDICINE
# 2       92604    CA         IRVINE  PEDIATRIC MEDICINE
# 3       92868    CA         ORANGE  PEDIATRIC MEDICINE
# 4       92868    CA         ORANGE  PEDIATRIC MEDICINE
# ..        ...   ...            ...                 ...
# 532     92868    CA         ORANGE  PEDIATRIC MEDICINE
# 533     90027    CA    LOS ANGELES  PEDIATRIC MEDICINE
# 534     94304    CA      PALO ALTO  PEDIATRIC MEDICINE
# 535     92833    CA      FULLERTON  PEDIATRIC MEDICINE
# 536     90027    CA    LOS ANGELES  PEDIATRIC MEDICINE
#
#                All Secondary Specialties Gender  \
# 0                                    NaN      M
# 1                     INFECTIOUS DISEASE      M
# 2                                    NaN      F
# 3    CARDIOVASCULAR DISEASE (CARDIOLOGY)      M
# 4    CARDIOVASCULAR DISEASE (CARDIOLOGY)      M
# ...

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1759 entries, 0 to 1758
# Data columns (total 9 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Zipcode                         1759 non-null   int64
#  1   Land Area sq meters             1759 non-null   object
#  2   Water Area sq meters            1759 non-null   object
#  3   Land Area sq miles              1759 non-null   float64
#  4   Water Area sq miles             1759 non-null   float64
#  5   Latitude                        1759 non-null   float64
#  6   Longitude                       1759 non-null   object
#  7   Population                      1759 non-null   float64
#  8   Population Density per sq mile  1759 non-null   float64
# dtypes: float64(5), int64(1), object(3)
# memory usage: 123.8+ KB

# %%
df4 = df4.rename(columns = {'Zipcode': 'ZIP Code'})
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1759 entries, 0 to 1758
# Data columns (total 9 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   ZIP Code                        1759 non-null   int64
#  1   Land Area sq meters             1759 non-null   object
#  2   Water Area sq meters            1759 non-null   object
#  3   Land Area sq miles              1759 non-null   float64
#  4   Water Area sq miles             1759 non-null   float64
#  5   Latitude                        1759 non-null   float64
#  6   Longitude                       1759 non-null   object
#  7   Population                      1759 non-null   float64
#  8   Population Density per sq mile  1759 non-null   float64
# dtypes: float64(5), int64(1), object(3)
# memory usage: 123.8+ KB

# %%
df_totall = pd.merge(df_tota, df4, on='ZIP Code', how='inner')
df_totall
# Out:
#      ZIP Code State      City/Town   Primary Specialty  \
# 0       94304    CA      PALO ALTO  PEDIATRIC MEDICINE
# 1       91402    CA  PANORAMA CITY  PEDIATRIC MEDICINE
# 2       92604    CA         IRVINE  PEDIATRIC MEDICINE
# 3       92868    CA         ORANGE  PEDIATRIC MEDICINE
# 4       92868    CA         ORANGE  PEDIATRIC MEDICINE
# ..        ...   ...            ...                 ...
# 532     92868    CA         ORANGE  PEDIATRIC MEDICINE
# 533     90027    CA    LOS ANGELES  PEDIATRIC MEDICINE
# 534     94304    CA      PALO ALTO  PEDIATRIC MEDICINE
# 535     92833    CA      FULLERTON  PEDIATRIC MEDICINE
# 536     90027    CA    LOS ANGELES  PEDIATRIC MEDICINE
#
#                All Secondary Specialties Gender  \
# 0                                    NaN      M
# 1                     INFECTIOUS DISEASE      M
# 2                                    NaN      F
# 3    CARDIOVASCULAR DISEASE (CARDIOLOGY)      M
# 4    CARDIOVASCULAR DISEASE (CARDIOLOGY)      M
# ...

# %%
df5 = df5.rename(columns = {'Zipcode': 'ZIP Code'})
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1759 entries, 0 to 1758
# Data columns (total 7 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   ZIP Code                   1759 non-null   int64
#  1   Population                 1759 non-null   float64
#  2   Per Capita Income          1741 non-null   float64
#  3   Poverty Count              1759 non-null   float64
#  4   Poverty Rate               1735 non-null   float64
#  5   Insurance coverage status  1759 non-null   float64
#  6   Coverage Rate              1735 non-null   float64
# dtypes: float64(6), int64(1)
# memory usage: 96.3 KB

# %%
all_datas = pd.merge(df_totall, df5, on='ZIP Code', how='inner')
all_datas
# Out:
#      ZIP Code State      City/Town   Primary Specialty  \
# 0       94304    CA      PALO ALTO  PEDIATRIC MEDICINE
# 1       91402    CA  PANORAMA CITY  PEDIATRIC MEDICINE
# 2       92604    CA         IRVINE  PEDIATRIC MEDICINE
# 3       92868    CA         ORANGE  PEDIATRIC MEDICINE
# 4       92868    CA         ORANGE  PEDIATRIC MEDICINE
# ..        ...   ...            ...                 ...
# 532     92868    CA         ORANGE  PEDIATRIC MEDICINE
# 533     90027    CA    LOS ANGELES  PEDIATRIC MEDICINE
# 534     94304    CA      PALO ALTO  PEDIATRIC MEDICINE
# 535     92833    CA      FULLERTON  PEDIATRIC MEDICINE
# 536     90027    CA    LOS ANGELES  PEDIATRIC MEDICINE
#
#                All Secondary Specialties Gender  \
# 0                                    NaN      M
# 1                     INFECTIOUS DISEASE      M
# 2                                    NaN      F
# 3    CARDIOVASCULAR DISEASE (CARDIOLOGY)      M
# 4    CARDIOVASCULAR DISEASE (CARDIOLOGY)      M
# ...
