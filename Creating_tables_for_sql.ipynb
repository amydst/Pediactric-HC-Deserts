# %%
import pandas as pd

# %%
Path1 = "Finall_doctors.csv"

# %%
df = pd.read_csv(Path1)

# %%
df.rename(columns ={'Zip Code': 'ZIP Code'}, inplace = True)

# %%
df
# Out:
#       ZIP Code Primary Practice  Count Of Licensees
# 0        90001       Pediatrics                   1
# 1        90002       Pediatrics                   2
# 2        90003       Pediatrics                   2
# 3        90004       Pediatrics                   7
# 4        90005       Pediatrics                   3
# ...        ...              ...                 ...
# 1848     96151       Pediatrics                   0
# 1849     96158       Pediatrics                   0
# 1850     96160       Pediatrics                   1
# 1851     96161       Pediatrics                   1
# 1852     96162       Pediatrics                   0
#
# [1853 rows x 3 columns]

# %%
import pandas as pd

# %%
Path2 = 'income_per_code.csv'

# %%
df2 = pd.read_csv(Path2)

# %%
df2
# Out:
#       ZIP Code  Household Median Income  Household Mean Income  \
# 0        89010                  32847.0                53109.0
# 1        89019                  56765.0                86818.0
# 2        89060                  45833.0                56469.0
# 3        89061                  56865.0                62940.0
# 4        89439                  60547.0                89705.0
# ...        ...                      ...                    ...
# 1764     96148                  81833.0               106323.0
# 1765     96150                  62541.0                95949.0
# 1766     96155                      NaN                    NaN
# 1767     96161                 100205.0               148847.0
# 1768     97635                      NaN                73435.0
#
#       Family Median Income  Family Mean Income  \
# 0                  44750.0             66807.0
# 1                  89558.0            131125.0
# 2                  52552.0             60592.0
# ...

# %%
import pandas as pd

# %%
Path3 = 'pop_density_per_zip.csv'

# %%
df3 = pd.read_csv(Path3)

# %%
df3
# Out:
#       Zipcode Land Area sq meters Water Area sq meters  Land Area sq miles  \
# 0       89060       1,164,029,185               83,993             449.434
# 1       89061         165,855,694               10,631              64.037
# 2       89439          42,115,079              336,966              16.261
# 3       90001           8,495,419                    0               3.280
# 4       90002           7,750,658                    0               2.993
# ...       ...                 ...                  ...                 ...
# 1754    96148           5,411,110                    0               2.089
# 1755    96150         422,599,296           14,431,182             163.167
# 1756    96155          97,744,600               76,028              37.739
# 1757    96161         680,238,466            9,131,164             262.642
# 1758    97635         135,078,015              153,823              52.154
#
#       Water Area sq miles   Latitude     Longitude  Population  \
# ...

# %%
df3.rename(columns = {'Zipcode' : 'ZIP Code'}, inplace = True)
df3
# Out:
#       ZIP Code Land Area sq meters Water Area sq meters  Land Area sq miles  \
# 0        89060       1,164,029,185               83,993             449.434
# 1        89061         165,855,694               10,631              64.037
# 2        89439          42,115,079              336,966              16.261
# 3        90001           8,495,419                    0               3.280
# 4        90002           7,750,658                    0               2.993
# ...        ...                 ...                  ...                 ...
# 1754     96148           5,411,110                    0               2.089
# 1755     96150         422,599,296           14,431,182             163.167
# 1756     96155          97,744,600               76,028              37.739
# 1757     96161         680,238,466            9,131,164             262.642
# 1758     97635         135,078,015              153,823              52.154
#
# ...

# %%
df_1_2 = pd.merge(df2, df, on='ZIP Code', how='outer')

list(df_1_2)
# Out:
# ['ZIP Code',
#  'Household Median Income',
#  'Household Mean Income',
#  'Family Median Income',
#  'Family Mean Income',
#  'Married-couple Family Median Income',
#  'Married-couple Family Mean Income',
#  'Nonfamily Household Median Income',
#  'Nonfamily Household Mean Income',
#  'Primary Practice',
#  'Count Of Licensees']

# %%
df_1_2.rename(columns = {'Count Of Licensees' : 'Number of Pediatricians'}, inplace = True)
df_1_2
# Out:
#       ZIP Code  Household Median Income  Household Mean Income  \
# 0        89010                  32847.0                53109.0
# 1        89019                  56765.0                86818.0
# 2        89060                  45833.0                56469.0
# 3        89061                  56865.0                62940.0
# 4        89439                  60547.0                89705.0
# ...        ...                      ...                    ...
# 2238     96158                      NaN                    NaN
# 2239     96160                      NaN                    NaN
# 2240     96161                 100205.0               148847.0
# 2241     96162                      NaN                    NaN
# 2242     97635                      NaN                73435.0
#
#       Family Median Income  Family Mean Income  \
# 0                  44750.0             66807.0
# 1                  89558.0            131125.0
# 2                  52552.0             60592.0
# ...

# %%
df_1_2_3 = pd.merge(df_1_2, df3, on='ZIP Code', how='outer')
df_1_2_3
# Out:
#       ZIP Code  Household Median Income  Household Mean Income  \
# 0        89010                  32847.0                53109.0
# 1        89019                  56765.0                86818.0
# 2        89060                  45833.0                56469.0
# 3        89061                  56865.0                62940.0
# 4        89439                  60547.0                89705.0
# ...        ...                      ...                    ...
# 2238     96158                      NaN                    NaN
# 2239     96160                      NaN                    NaN
# 2240     96161                 100205.0               148847.0
# 2241     96162                      NaN                    NaN
# 2242     97635                      NaN                73435.0
#
#       Family Median Income  Family Mean Income  \
# 0                  44750.0             66807.0
# 1                  89558.0            131125.0
# 2                  52552.0             60592.0
# ...

# %%
df_1_2_3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2243 entries, 0 to 2242
# Data columns (total 19 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   ZIP Code                             2243 non-null   int64
#  1   Household Median Income              1600 non-null   float64
#  2   Household Mean Income                1676 non-null   float64
#  3   Family Median Income                 1553 non-null   float64
#  4   Family Mean Income                   1637 non-null   float64
#  5   Married-couple Family Median Income  1523 non-null   float64
#  6   Married-couple Family Mean Income    132 non-null    float64
#  7   Nonfamily Household Median Income    1474 non-null   float64
#  8   Nonfamily Household Mean Income      1598 non-null   float64
#  9   Primary Practice                     1853 non-null   object
#  10  Number of Pediatricians              1853 non-null   float64
# ...

# %%
df_1_2_3['Primary Practice'] = df_1_2_3['Primary Practice'].astype(str)
df_1_2_3['Land Area sq meters'] = df_1_2_3['Land Area sq meters'].str.replace(',', '').astype(float)
df_1_2_3['Water Area sq meters'] = df_1_2_3['Water Area sq meters'].str.replace(',', '').astype(float)
df_1_2_3['Longitude'] = df_1_2_3['Longitude'].str.replace('−', '-')
df_1_2_3['Longitude'] = df_1_2_3['Longitude'].str.replace(',', '')
df_1_2_3['Longitude'] = df_1_2_3['Longitude'].str.strip()
df_1_2_3['Longitude'] = pd.to_numeric(df_1_2_3['Longitude'], errors='coerce')
df_1_2_3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2243 entries, 0 to 2242
# Data columns (total 19 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   ZIP Code                             2243 non-null   int64
#  1   Household Median Income              1600 non-null   float64
#  2   Household Mean Income                1676 non-null   float64
#  3   Family Median Income                 1553 non-null   float64
#  4   Family Mean Income                   1637 non-null   float64
#  5   Married-couple Family Median Income  1523 non-null   float64
#  6   Married-couple Family Mean Income    132 non-null    float64
#  7   Nonfamily Household Median Income    1474 non-null   float64
#  8   Nonfamily Household Mean Income      1598 non-null   float64
#  9   Primary Practice                     2243 non-null   object
#  10  Number of Pediatricians              1853 non-null   float64
# ...

# %%
df_1_2_3['Primary Practice'] = df_1_2_3['Primary Practice'].astype(str)

# %%
df_1_2_3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2243 entries, 0 to 2242
# Data columns (total 19 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   ZIP Code                             2243 non-null   int64
#  1   Household Median Income              1600 non-null   float64
#  2   Household Mean Income                1676 non-null   float64
#  3   Family Median Income                 1553 non-null   float64
#  4   Family Mean Income                   1637 non-null   float64
#  5   Married-couple Family Median Income  1523 non-null   float64
#  6   Married-couple Family Mean Income    132 non-null    float64
#  7   Nonfamily Household Median Income    1474 non-null   float64
#  8   Nonfamily Household Mean Income      1598 non-null   float64
#  9   Primary Practice                     2243 non-null   object
#  10  Number of Pediatricians              1853 non-null   float64
# ...

# %%
df_1_2_3.columns = df_1_2_3.columns.str.strip()

drop_columns = [
    'Land Area sq meters',
    'Water Area sq meters'
]

df_1_2_3 = df_1_2_3.drop(columns=drop_columns)

df_1_2_3.head()
# Out:
#    ZIP Code  Household Median Income  Household Mean Income  \
# 0     89010                  32847.0                53109.0
# 1     89019                  56765.0                86818.0
# 2     89060                  45833.0                56469.0
# 3     89061                  56865.0                62940.0
# 4     89439                  60547.0                89705.0
#
#    Family Median Income  Family Mean Income  \
# 0               44750.0             66807.0
# 1               89558.0            131125.0
# 2               52552.0             60592.0
# 3               61148.0             69431.0
# 4               81875.0            113306.0
#
#    Married-couple Family Median Income  Married-couple Family Mean Income  \
# 0                              67813.0                                NaN
# 1                                  NaN                                NaN
# 2                              53488.0                                NaN
# ...

# %%
df_1_2_3['Primary Practice'].value_counts()
# Out:
# Primary Practice
# Pediatrics    1853
# nan            390
# Name: count, dtype: int64

# %%
df_1_2_3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2243 entries, 0 to 2242
# Data columns (total 17 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   ZIP Code                             2243 non-null   int64
#  1   Household Median Income              1600 non-null   float64
#  2   Household Mean Income                1676 non-null   float64
#  3   Family Median Income                 1553 non-null   float64
#  4   Family Mean Income                   1637 non-null   float64
#  5   Married-couple Family Median Income  1523 non-null   float64
#  6   Married-couple Family Mean Income    132 non-null    float64
#  7   Nonfamily Household Median Income    1474 non-null   float64
#  8   Nonfamily Household Mean Income      1598 non-null   float64
#  9   Primary Practice                     2243 non-null   object
#  10  Number of Pediatricians              1853 non-null   float64
# ...

# %%
df_1_2_3['Primary Practice'] = df_1_2_3['Primary Practice'].astype('string')

# %%
df_1_2_3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2243 entries, 0 to 2242
# Data columns (total 17 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   ZIP Code                             2243 non-null   int64
#  1   Household Median Income              1600 non-null   float64
#  2   Household Mean Income                1676 non-null   float64
#  3   Family Median Income                 1553 non-null   float64
#  4   Family Mean Income                   1637 non-null   float64
#  5   Married-couple Family Median Income  1523 non-null   float64
#  6   Married-couple Family Mean Income    132 non-null    float64
#  7   Nonfamily Household Median Income    1474 non-null   float64
#  8   Nonfamily Household Mean Income      1598 non-null   float64
#  9   Primary Practice                     2243 non-null   string
#  10  Number of Pediatricians              1853 non-null   float64
# ...

# %%
Pathpov = "poverty_rate_per_zip.csv"

# %%
df_poverty = pd.read_csv(Pathpov)

# %%
df_poverty
# Out:
#       Zipcode  Population  Per Capita Income  Poverty Count  Poverty Rate  \
# 0       89060     12198.0            31138.0         2183.0     17.896376
# 1       89061      7529.0            33771.0          486.0      6.455041
# 2       89439      1639.0            65281.0           93.0      5.674192
# 3       90001     57652.0            17994.0        12186.0     21.137168
# 4       90002     53108.0            18262.0        12740.0     23.988853
# ...       ...         ...                ...            ...           ...
# 1754    96148       630.0            51839.0           15.0      2.380952
# 1755    96150     29457.0            51115.0         3263.0     11.077163
# 1756    96155         0.0       -666666666.0            0.0           NaN
# 1757    96161     19146.0            69217.0         1602.0      8.367283
# 1758    97635       345.0            32130.0           27.0      7.826087
#
#       Insurance coverage status  Coverage Rate
# ...

# %%
df_poverty.rename(columns = {'Zipcode' : 'ZIP Code'}, inplace = True)

# %%
df_poverty
# Out:
#       ZIP Code  Population  Per Capita Income  Poverty Count  Poverty Rate  \
# 0        89060     12198.0            31138.0         2183.0     17.896376
# 1        89061      7529.0            33771.0          486.0      6.455041
# 2        89439      1639.0            65281.0           93.0      5.674192
# 3        90001     57652.0            17994.0        12186.0     21.137168
# 4        90002     53108.0            18262.0        12740.0     23.988853
# ...        ...         ...                ...            ...           ...
# 1754     96148       630.0            51839.0           15.0      2.380952
# 1755     96150     29457.0            51115.0         3263.0     11.077163
# 1756     96155         0.0       -666666666.0            0.0           NaN
# 1757     96161     19146.0            69217.0         1602.0      8.367283
# 1758     97635       345.0            32130.0           27.0      7.826087
#
#       Insurance coverage status  Coverage Rate
# ...

# %%
droping_columns = [
    'Population',
    'Per Capita Income',    
]
df_poverty = df_poverty.drop(columns=droping_columns)
df_poverty
# Out:
#       ZIP Code  Poverty Count  Poverty Rate  Insurance coverage status  \
# 0        89060         2183.0     17.896376                    11857.0
# 1        89061          486.0      6.455041                     7529.0
# 2        89439           93.0      5.674192                     1639.0
# 3        90001        12186.0     21.137168                    57639.0
# 4        90002        12740.0     23.988853                    53100.0
# ...        ...            ...           ...                        ...
# 1754     96148           15.0      2.380952                      630.0
# 1755     96150         3263.0     11.077163                    29240.0
# 1756     96155            0.0           NaN                        0.0
# 1757     96161         1602.0      8.367283                    19146.0
# 1758     97635           27.0      7.826087                      345.0
#
#       Coverage Rate
# 0         97.204460
# 1        100.000000
# 2        100.000000
# 3         99.977451
# ...

# %%
df_1_2_3_poverty = pd.merge(df_1_2_3, df_poverty, on='ZIP Code', how='outer')
df_1_2_3_poverty
# Out:
#       ZIP Code  Household Median Income  Household Mean Income  \
# 0        89010                  32847.0                53109.0
# 1        89019                  56765.0                86818.0
# 2        89060                  45833.0                56469.0
# 3        89061                  56865.0                62940.0
# 4        89439                  60547.0                89705.0
# ...        ...                      ...                    ...
# 2238     96158                      NaN                    NaN
# 2239     96160                      NaN                    NaN
# 2240     96161                 100205.0               148847.0
# 2241     96162                      NaN                    NaN
# 2242     97635                      NaN                73435.0
#
#       Family Median Income  Family Mean Income  \
# 0                  44750.0             66807.0
# 1                  89558.0            131125.0
# 2                  52552.0             60592.0
# ...

# %%
list(df_1_2_3_poverty)
# Out:
# ['ZIP Code',
#  'Household Median Income',
#  'Household Mean Income',
#  'Family Median Income',
#  'Family Mean Income',
#  'Married-couple Family Median Income',
#  'Married-couple Family Mean Income',
#  'Nonfamily Household Median Income',
#  'Nonfamily Household Mean Income',
#  'Primary Practice',
#  'Number of Pediatricians',
#  'Land Area sq miles',
#  'Water Area sq miles',
#  'Latitude',
#  'Longitude',
#  'Population',
#  'Population Density per sq mile',
#  'Poverty Count',
#  'Poverty Rate',
#  'Insurance coverage status',
#  'Coverage Rate']

# %%
df_1_2_3_poverty.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2243 entries, 0 to 2242
# Data columns (total 21 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   ZIP Code                             2243 non-null   int64
#  1   Household Median Income              1600 non-null   float64
#  2   Household Mean Income                1676 non-null   float64
#  3   Family Median Income                 1553 non-null   float64
#  4   Family Mean Income                   1637 non-null   float64
#  5   Married-couple Family Median Income  1523 non-null   float64
#  6   Married-couple Family Mean Income    132 non-null    float64
#  7   Nonfamily Household Median Income    1474 non-null   float64
#  8   Nonfamily Household Mean Income      1598 non-null   float64
#  9   Primary Practice                     2243 non-null   string
#  10  Number of Pediatricians              1853 non-null   float64
# ...

# %%
df_1_2_3_poverty.to_csv("Demographics.csv", index = False)

# %%
import pandas as pd

# %%
Path4 = 'kids_per_code.csv'

# %%
df4 = pd.read_csv(Path4)

# %%
df4
# Out:
#       ZIP Code  Population Under 18 years (Selected)  Total Population  \
# 0        89010                                    71               461
# 1        89019                                   146              2312
# 2        89060                                  1917             12198
# 3        89061                                   971              7529
# 4        89439                                   192              1639
# ...        ...                                   ...               ...
# 1803     96148                                    69               630
# 1804     96150                                  4779             29457
# 1805     96155                                     0                 0
# 1806     96161                                  4062             19146
# 1807     97635                                   123               345
#
#       Population Under 5 years  Population 5 to 9 years  \
# 0                           20                       28
# ...

# %%
list(df4)
# Out:
# ['ZIP Code',
#  'Population Under 18 years (Selected)',
#  'Total Population',
#  'Population Under 5 years',
#  'Population 5 to 9 years',
#  'Population 10 to 14 years',
#  'Population 15 to 19 years',
#  'Percent Population Under 5 years',
#  'Percent Population 5 to 9 years',
#  'Percent Population 10 to 14 years',
#  'Percent Population Under 18 years (Selected)',
#  'Male Population Under 5 years',
#  'Male Population 5 to 9 years',
#  'Male Population 10 to 14 years',
#  'Female Population Under 5 years',
#  'Female Population 5 to 9 years',
#  'Female Population 10 to 14 years',
#  'Female Population Under 18 years (Selected)']

# %%
columns_to_drop = [
    'Population Under 5 years',
    'Population 5 to 9 years',
    'Population 10 to 14 years',
    'Population 15 to 19 years',
    'Percent Population Under 5 years',
    'Percent Population 5 to 9 years',
    'Percent Population 10 to 14 years',
    'Male Population Under 5 years',
    'Male Population 5 to 9 years',
    'Male Population 10 to 14 years',
    'Female Population Under 5 years',
    'Female Population 5 to 9 years',
    'Female Population 10 to 14 years'
]

df4 = df4.drop(columns=columns_to_drop)

list(df4)
# Out:
# ['ZIP Code',
#  'Population Under 18 years (Selected)',
#  'Total Population',
#  'Percent Population Under 18 years (Selected)',
#  'Female Population Under 18 years (Selected)']

# %%
df4['Male Population Under 18 years (Selected)'] = df4['Population Under 18 years (Selected)'] - df4['Female Population Under 18 years (Selected)']
df4
# Out:
#       ZIP Code  Population Under 18 years (Selected)  Total Population  \
# 0        89010                                    71               461
# 1        89019                                   146              2312
# 2        89060                                  1917             12198
# 3        89061                                   971              7529
# 4        89439                                   192              1639
# ...        ...                                   ...               ...
# 1803     96148                                    69               630
# 1804     96150                                  4779             29457
# 1805     96155                                     0                 0
# 1806     96161                                  4062             19146
# 1807     97635                                   123               345
#
#       Percent Population Under 18 years (Selected)  \
# 0                                             15.4
# ...

# %%
df4.rename(columns = {
    'Population Under 18 years (Selected)' : 'Population Under 18 years',
    'Percent Population Under 18 years (Selected)' : 'Percent Population Under 18 years',
    'Female Population Under 18 years (Selected)' : 'Female Population Under 18 years',
    'Male Population Under 18 years (Selected)' : 'Male Population Under 18 years'
}, inplace = True)
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1808 entries, 0 to 1807
# Data columns (total 6 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   ZIP Code                           1808 non-null   int64
#  1   Population Under 18 years          1808 non-null   int64
#  2   Total Population                   1808 non-null   int64
#  3   Percent Population Under 18 years  1771 non-null   float64
#  4   Female Population Under 18 years   1808 non-null   int64
#  5   Male Population Under 18 years     1808 non-null   int64
# dtypes: float64(1), int64(5)
# memory usage: 84.9 KB

# %%
df4['ZIP Code'] = df4['ZIP Code'].astype('string')

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1808 entries, 0 to 1807
# Data columns (total 6 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   ZIP Code                           1808 non-null   string
#  1   Population Under 18 years          1808 non-null   int64
#  2   Total Population                   1808 non-null   int64
#  3   Percent Population Under 18 years  1771 non-null   float64
#  4   Female Population Under 18 years   1808 non-null   int64
#  5   Male Population Under 18 years     1808 non-null   int64
# dtypes: float64(1), int64(4), string(1)
# memory usage: 84.9 KB

# %%
df4.to_csv("Population.csv", index = False)
