# %%
import pandas as pd

# %%
Path1 = "Finall_doctors.csv"

# %%
df= pd.read_csv(Path1)

# %%
df
# Out:
#       Zip Code Primary Practice  Count Of Licensees
# 0        90001       Pediatrics                   1
# 1        90002       Pediatrics                   2
# 2        90003       Pediatrics                   2
# 3        90004       Pediatrics                   7
# 4        90005       Pediatrics                   3
# ...        ...              ...                 ...
# 1848     96151       Pediatrics                   0
# 1849     96158       Pediatrics                   0
# 1850     96160       Pediatrics                   1
# 1851     96161       Pediatrics                   1
# 1852     96162       Pediatrics                   0
#
# [1853 rows x 3 columns]

# %%
df.rename(columns ={'Zip Code': 'ZIP Code'}, inplace = True)

# %%
df["ZIP Code"].value_counts()
# Out:
# ZIP Code
# 90001    1
# 94539    1
# 94537    1
# 94536    1
# 94535    1
#         ..
# 92274    1
# 92270    1
# 92264    1
# 92263    1
# 96162    1
# Name: count, Length: 1853, dtype: int64

# %%
Path2 = 'kids_per_code.csv'

# %%
df2= pd.read_csv(Path2)

# %%
df2.head()
# Out:
#    ZIP Code  Population Under 18 years (Selected)  Total Population  \
# 0     89010                                    71               461
# 1     89019                                   146              2312
# 2     89060                                  1917             12198
# 3     89061                                   971              7529
# 4     89439                                   192              1639
#
#    Population Under 5 years  Population 5 to 9 years  \
# 0                        20                       28
# 1                        56                       31
# 2                       509                      662
# 3                        69                      411
# 4                        42                      111
#
#    Population 10 to 14 years  Population 15 to 19 years  \
# 0                         23                         10
# 1                         28                         76
# 2                        372                        510
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1808 entries, 0 to 1807
# Data columns (total 18 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   ZIP Code                                      1808 non-null   int64
#  1   Population Under 18 years (Selected)          1808 non-null   int64
#  2   Total Population                              1808 non-null   int64
#  3   Population Under 5 years                      1808 non-null   int64
#  4   Population 5 to 9 years                       1808 non-null   int64
#  5   Population 10 to 14 years                     1808 non-null   int64
#  6   Population 15 to 19 years                     1808 non-null   int64
#  7   Percent Population Under 5 years              1771 non-null   float64
#  8   Percent Population 5 to 9 years               1771 non-null   float64
# ...

# %%
Path3 = 'income_per_code.csv'

# %%
df3= pd.read_csv(Path3)

# %%
df3.head()
# Out:
#    ZIP Code  Household Median Income  Household Mean Income  \
# 0     89010                  32847.0                53109.0
# 1     89019                  56765.0                86818.0
# 2     89060                  45833.0                56469.0
# 3     89061                  56865.0                62940.0
# 4     89439                  60547.0                89705.0
#
#    Family Median Income  Family Mean Income  \
# 0               44750.0             66807.0
# 1               89558.0            131125.0
# 2               52552.0             60592.0
# 3               61148.0             69431.0
# 4               81875.0            113306.0
#
#    Married-couple Family Median Income  Married-couple Family Mean Income  \
# 0                              67813.0                                NaN
# 1                                  NaN                                NaN
# 2                              53488.0                                NaN
# ...

# %%
Path4 = 'pop_density_per_zip.csv'

# %%
df4= pd.read_csv(Path4)

# %%
df4.head()
# Out:
#    Zipcode Land Area sq meters Water Area sq meters  Land Area sq miles  \
# 0    89060       1,164,029,185               83,993             449.434
# 1    89061         165,855,694               10,631              64.037
# 2    89439          42,115,079              336,966              16.261
# 3    90001           8,495,419                    0               3.280
# 4    90002           7,750,658                    0               2.993
#
#    Water Area sq miles   Latitude     Longitude  Population  \
# 0                0.032  36.391556  −116.0575681     10692.0
# 1                0.004  36.070110  −115.9062487      5537.0
# 2                0.130  39.523352  −119.9903835      1244.0
# 3                0.000  33.973665  −118.2490388     58974.0
# 4                0.000  33.948987  −118.2467796     53402.0
#
#    Population Density per sq mile
# 0                       23.789922
# 1                       86.465637
# 2                       76.502060
# ...

# %%
Path5 = 'poverty_rate_per_zip.csv'

# %%
df5= pd.read_csv(Path5)

# %%
df5.head()
# Out:
#    Zipcode  Population  Per Capita Income  Poverty Count  Poverty Rate  \
# 0    89060     12198.0            31138.0         2183.0     17.896376
# 1    89061      7529.0            33771.0          486.0      6.455041
# 2    89439      1639.0            65281.0           93.0      5.674192
# 3    90001     57652.0            17994.0        12186.0     21.137168
# 4    90002     53108.0            18262.0        12740.0     23.988853
#
#    Insurance coverage status  Coverage Rate
# 0                    11857.0      97.204460
# 1                     7529.0     100.000000
# 2                     1639.0     100.000000
# 3                    57639.0      99.977451
# 4                    53100.0      99.984936

# %%
df_1_2 = pd.merge(df2, df, on='ZIP Code', how='outer')

list(df_1_2)
# Out:
# ['ZIP Code',
#  'Population Under 18 years (Selected)',
#  'Total Population',
#  'Population Under 5 years',
#  'Population 5 to 9 years',
#  'Population 10 to 14 years',
#  'Population 15 to 19 years',
#  'Percent Population Under 5 years',
#  'Percent Population 5 to 9 years',
#  'Percent Population 10 to 14 years',
#  'Percent Population Under 18 years (Selected)',
#  'Male Population Under 5 years',
#  'Male Population 5 to 9 years',
#  'Male Population 10 to 14 years',
#  'Female Population Under 5 years',
#  'Female Population 5 to 9 years',
#  'Female Population 10 to 14 years',
#  'Female Population Under 18 years (Selected)',
#  'Primary Practice',
#  'Count Of Licensees']

# %%
df_1_2
# Out:
#       ZIP Code  Population Under 18 years (Selected)  Total Population  \
# 0        89010                                  71.0             461.0
# 1        89019                                 146.0            2312.0
# 2        89060                                1917.0           12198.0
# 3        89061                                 971.0            7529.0
# 4        89439                                 192.0            1639.0
# ...        ...                                   ...               ...
# 2248     96158                                   NaN               NaN
# 2249     96160                                   NaN               NaN
# 2250     96161                                4062.0           19146.0
# 2251     96162                                   NaN               NaN
# 2252     97635                                 123.0             345.0
#
#       Population Under 5 years  Population 5 to 9 years  \
# 0                         20.0                     28.0
# ...

# %%
df_1_2 = pd.merge(df, df2, on='ZIP Code', how='outer')
df_1_2
# Out:
#       ZIP Code Primary Practice  Count Of Licensees  \
# 0        89010              NaN                 NaN
# 1        89019              NaN                 NaN
# 2        89060              NaN                 NaN
# 3        89061              NaN                 NaN
# 4        89439              NaN                 NaN
# ...        ...              ...                 ...
# 2248     96158       Pediatrics                 0.0
# 2249     96160       Pediatrics                 1.0
# 2250     96161       Pediatrics                 1.0
# 2251     96162       Pediatrics                 0.0
# 2252     97635              NaN                 NaN
#
#       Population Under 18 years (Selected)  Total Population  \
# 0                                     71.0             461.0
# 1                                    146.0            2312.0
# 2                                   1917.0           12198.0
# 3                                    971.0            7529.0
# ...

# %%
df_1_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2253 entries, 0 to 2252
# Data columns (total 20 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   ZIP Code                                      2253 non-null   int64
#  1   Primary Practice                              1853 non-null   object
#  2   Count Of Licensees                            1853 non-null   float64
#  3   Population Under 18 years (Selected)          1808 non-null   float64
#  4   Total Population                              1808 non-null   float64
#  5   Population Under 5 years                      1808 non-null   float64
#  6   Population 5 to 9 years                       1808 non-null   float64
#  7   Population 10 to 14 years                     1808 non-null   float64
#  8   Population 15 to 19 years                     1808 non-null   float64
# ...

# %%
df_1_2_3 = pd.merge(df_1_2, df3, on='ZIP Code', how='outer')
df_1_2_3
# Out:
#       ZIP Code Primary Practice  Count Of Licensees  \
# 0        89010              NaN                 NaN
# 1        89019              NaN                 NaN
# 2        89060              NaN                 NaN
# 3        89061              NaN                 NaN
# 4        89439              NaN                 NaN
# ...        ...              ...                 ...
# 2254     96158       Pediatrics                 0.0
# 2255     96160       Pediatrics                 1.0
# 2256     96161       Pediatrics                 1.0
# 2257     96162       Pediatrics                 0.0
# 2258     97635              NaN                 NaN
#
#       Population Under 18 years (Selected)  Total Population  \
# 0                                     71.0             461.0
# 1                                    146.0            2312.0
# 2                                   1917.0           12198.0
# 3                                    971.0            7529.0
# ...

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1759 entries, 0 to 1758
# Data columns (total 9 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Zipcode                         1759 non-null   int64
#  1   Land Area sq meters             1759 non-null   object
#  2   Water Area sq meters            1759 non-null   object
#  3   Land Area sq miles              1759 non-null   float64
#  4   Water Area sq miles             1759 non-null   float64
#  5   Latitude                        1759 non-null   float64
#  6   Longitude                       1759 non-null   object
#  7   Population                      1759 non-null   float64
#  8   Population Density per sq mile  1759 non-null   float64
# dtypes: float64(5), int64(1), object(3)
# memory usage: 123.8+ KB

# %%
df4 = df4.rename(columns = {'Zipcode': 'ZIP Code'})
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1759 entries, 0 to 1758
# Data columns (total 9 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   ZIP Code                        1759 non-null   int64
#  1   Land Area sq meters             1759 non-null   object
#  2   Water Area sq meters            1759 non-null   object
#  3   Land Area sq miles              1759 non-null   float64
#  4   Water Area sq miles             1759 non-null   float64
#  5   Latitude                        1759 non-null   float64
#  6   Longitude                       1759 non-null   object
#  7   Population                      1759 non-null   float64
#  8   Population Density per sq mile  1759 non-null   float64
# dtypes: float64(5), int64(1), object(3)
# memory usage: 123.8+ KB

# %%
df_1_2_3_4 = pd.merge(df_1_2_3, df4, on='ZIP Code', how='outer')
df_1_2_3_4
# Out:
#       ZIP Code Primary Practice  Count Of Licensees  \
# 0        89010              NaN                 NaN
# 1        89019              NaN                 NaN
# 2        89060              NaN                 NaN
# 3        89061              NaN                 NaN
# 4        89439              NaN                 NaN
# ...        ...              ...                 ...
# 2254     96158       Pediatrics                 0.0
# 2255     96160       Pediatrics                 1.0
# 2256     96161       Pediatrics                 1.0
# 2257     96162       Pediatrics                 0.0
# 2258     97635              NaN                 NaN
#
#       Population Under 18 years (Selected)  Total Population  \
# 0                                     71.0             461.0
# 1                                    146.0            2312.0
# 2                                   1917.0           12198.0
# 3                                    971.0            7529.0
# ...

# %%
df5 = df5.rename(columns = {'Zipcode': 'ZIP Code'})
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1759 entries, 0 to 1758
# Data columns (total 7 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   ZIP Code                   1759 non-null   int64
#  1   Population                 1759 non-null   float64
#  2   Per Capita Income          1741 non-null   float64
#  3   Poverty Count              1759 non-null   float64
#  4   Poverty Rate               1735 non-null   float64
#  5   Insurance coverage status  1759 non-null   float64
#  6   Coverage Rate              1735 non-null   float64
# dtypes: float64(6), int64(1)
# memory usage: 96.3 KB

# %%
all_datas = pd.merge(df_1_2_3_4, df5, on='ZIP Code', how='outer')
all_datas
# Out:
#       ZIP Code Primary Practice  Count Of Licensees  \
# 0        89010              NaN                 NaN
# 1        89019              NaN                 NaN
# 2        89060              NaN                 NaN
# 3        89061              NaN                 NaN
# 4        89439              NaN                 NaN
# ...        ...              ...                 ...
# 2254     96158       Pediatrics                 0.0
# 2255     96160       Pediatrics                 1.0
# 2256     96161       Pediatrics                 1.0
# 2257     96162       Pediatrics                 0.0
# 2258     97635              NaN                 NaN
#
#       Population Under 18 years (Selected)  Total Population  \
# 0                                     71.0             461.0
# 1                                    146.0            2312.0
# 2                                   1917.0           12198.0
# 3                                    971.0            7529.0
# ...

# %%
list(all_datas)
# Out:
# ['ZIP Code',
#  'Primary Practice',
#  'Count Of Licensees',
#  'Population Under 18 years (Selected)',
#  'Total Population',
#  'Population Under 5 years',
#  'Population 5 to 9 years',
#  'Population 10 to 14 years',
#  'Population 15 to 19 years',
#  'Percent Population Under 5 years',
#  'Percent Population 5 to 9 years',
#  'Percent Population 10 to 14 years',
#  'Percent Population Under 18 years (Selected)',
#  'Male Population Under 5 years',
#  'Male Population 5 to 9 years',
#  'Male Population 10 to 14 years',
#  'Female Population Under 5 years',
#  'Female Population 5 to 9 years',
#  'Female Population 10 to 14 years',
#  'Female Population Under 18 years (Selected)',
#  'Household Median Income',
#  'Household Mean Income',
#  'Family Median Income',
#  'Family Mean Income',
#  'Married-couple Family Median Income',
#  'Married-couple Family Mean Income',
#  'Nonfamily Household Median Income',
#  'Nonfamily Household Mean Income',
#  'Land Area sq meters',
# ...

# %%
column_to_drop = { 
    'Population Under 5 years',
    'Population 5 to 9 years',
    'Population 10 to 14 years',
    'Population 15 to 19 years',
    'Percent Population Under 5 years',
    'Percent Population 5 to 9 years',
    'Percent Population 10 to 14 years',
    'Male Population Under 5 years',
    'Male Population 5 to 9 years',
    'Male Population 10 to 14 years',
    'Female Population Under 5 years',
    'Female Population 5 to 9 years',
    'Female Population 10 to 14 years',
    }

# %%
all_datas.to_csv("All_datas.csv", index = False)

# %%
columns_to_drop
