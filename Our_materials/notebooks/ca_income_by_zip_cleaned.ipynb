# %%
import pandas as pd

# %%
Path = "ca_income_by_zip.csv"

# %%
df = pd.read_csv(Path, header=0)

# %%
df.head()
# Out:
#            GEO_ID                  NAME               S1901_C01_001E  \
# 0       Geography  Geographic Area Name  Estimate!!Households!!Total
# 1     0400000US06            California                     13103114
# 2  8600000US89010           ZCTA5 89010                          185
# 3  8600000US89019           ZCTA5 89019                         1114
# 4  8600000US89060           ZCTA5 89060                         4348
#
#                        S1901_C01_001M  \
# 0  Margin of Error!!Households!!Total
# 1                               18542
# 2                                  52
# 3                                 299
# 4                                 344
#
#                                    S1901_C01_002E  \
# 0  Estimate!!Households!!Total!!Less than $10,000
# 1                                             4.7
# 2                                             0.0
# 3                                             1.3
# 4                                             8.6
#
# ...

# %%
list(df.columns)
# Out:
# ['GEO_ID',
#  'NAME',
#  'S1901_C01_001E',
#  'S1901_C01_001M',
#  'S1901_C01_002E',
#  'S1901_C01_002M',
#  'S1901_C01_003E',
#  'S1901_C01_003M',
#  'S1901_C01_004E',
#  'S1901_C01_004M',
#  'S1901_C01_005E',
#  'S1901_C01_005M',
#  'S1901_C01_006E',
#  'S1901_C01_006M',
#  'S1901_C01_007E',
#  'S1901_C01_007M',
#  'S1901_C01_008E',
#  'S1901_C01_008M',
#  'S1901_C01_009E',
#  'S1901_C01_009M',
#  'S1901_C01_010E',
#  'S1901_C01_010M',
#  'S1901_C01_011E',
#  'S1901_C01_011M',
#  'S1901_C01_012E',
#  'S1901_C01_012M',
#  'S1901_C01_013E',
#  'S1901_C01_013M',
#  'S1901_C01_014E',
#  'S1901_C01_014M',
#  'S1901_C01_015E',
#  'S1901_C01_015M',
#  'S1901_C01_016E',
#  'S1901_C01_016M',
#  'S1901_C02_001E',
#  'S1901_C02_001M',
#  'S1901_C02_002E',
#  'S1901_C02_002M',
#  'S1901_C02_003E',
#  'S1901_C02_003M',
#  'S1901_C02_004E',
#  'S1901_C02_004M',
#  'S1901_C02_005E',
#  'S1901_C02_005M',
#  'S1901_C02_006E',
#  'S1901_C02_006M',
#  'S1901_C02_007E',
#  'S1901_C02_007M',
# ...

# %%
df.rename(columns={'NAME' : 'Zip'}, inplace = True)
df.head()
# Out:
#            GEO_ID                   Zip               S1901_C01_001E  \
# 0       Geography  Geographic Area Name  Estimate!!Households!!Total
# 1     0400000US06            California                     13103114
# 2  8600000US89010           ZCTA5 89010                          185
# 3  8600000US89019           ZCTA5 89019                         1114
# 4  8600000US89060           ZCTA5 89060                         4348
#
#                        S1901_C01_001M  \
# 0  Margin of Error!!Households!!Total
# 1                               18542
# 2                                  52
# 3                                 299
# 4                                 344
#
#                                    S1901_C01_002E  \
# 0  Estimate!!Households!!Total!!Less than $10,000
# 1                                             4.7
# 2                                             0.0
# 3                                             1.3
# 4                                             8.6
#
# ...

# %%
df_cleaned = df.loc[:, ~df.columns.str.contains('m', case=False) & ~df.columns.str.contains('Unnamed')]
df_cleaned.head()
# Out:
#            GEO_ID                   Zip               S1901_C01_001E  \
# 0       Geography  Geographic Area Name  Estimate!!Households!!Total
# 1     0400000US06            California                     13103114
# 2  8600000US89010           ZCTA5 89010                          185
# 3  8600000US89019           ZCTA5 89019                         1114
# 4  8600000US89060           ZCTA5 89060                         4348
#
#                                    S1901_C01_002E  \
# 0  Estimate!!Households!!Total!!Less than $10,000
# 1                                             4.7
# 2                                             0.0
# 3                                             1.3
# 4                                             8.6
#
#                                     S1901_C01_003E  \
# 0  Estimate!!Households!!Total!!$10,000 to $14,999
# 1                                              3.9
# 2                                              4.9
# ...

# %%
list(df_cleaned.columns)
# Out:
# ['GEO_ID',
#  'Zip',
#  'S1901_C01_001E',
#  'S1901_C01_002E',
#  'S1901_C01_003E',
#  'S1901_C01_004E',
#  'S1901_C01_005E',
#  'S1901_C01_006E',
#  'S1901_C01_007E',
#  'S1901_C01_008E',
#  'S1901_C01_009E',
#  'S1901_C01_010E',
#  'S1901_C01_011E',
#  'S1901_C01_012E',
#  'S1901_C01_013E',
#  'S1901_C01_014E',
#  'S1901_C01_015E',
#  'S1901_C01_016E',
#  'S1901_C02_001E',
#  'S1901_C02_002E',
#  'S1901_C02_003E',
#  'S1901_C02_004E',
#  'S1901_C02_005E',
#  'S1901_C02_006E',
#  'S1901_C02_007E',
#  'S1901_C02_008E',
#  'S1901_C02_009E',
#  'S1901_C02_010E',
#  'S1901_C02_011E',
#  'S1901_C02_012E',
#  'S1901_C02_013E',
#  'S1901_C02_014E',
#  'S1901_C02_015E',
#  'S1901_C02_016E',
#  'S1901_C03_001E',
#  'S1901_C03_002E',
#  'S1901_C03_003E',
#  'S1901_C03_004E',
#  'S1901_C03_005E',
#  'S1901_C03_006E',
#  'S1901_C03_007E',
#  'S1901_C03_008E',
#  'S1901_C03_009E',
#  'S1901_C03_010E',
#  'S1901_C03_011E',
#  'S1901_C03_012E',
#  'S1901_C03_013E',
#  'S1901_C03_014E',
# ...

# %%
df_cleaned.columns = df_cleaned.iloc[0]
df_cleaned = df_cleaned.drop(index=0)
df_cleaned.head()
# Out:
# 0       Geography Geographic Area Name Estimate!!Households!!Total  \
# 1     0400000US06           California                    13103114
# 2  8600000US89010          ZCTA5 89010                         185
# 3  8600000US89019          ZCTA5 89019                        1114
# 4  8600000US89060          ZCTA5 89060                        4348
# 5  8600000US89061          ZCTA5 89061                        2527
#
# 0 Estimate!!Households!!Total!!Less than $10,000  \
# 1                                            4.7
# 2                                            0.0
# 3                                            1.3
# 4                                            8.6
# 5                                            4.2
#
# 0 Estimate!!Households!!Total!!$10,000 to $14,999  \
# 1                                             3.9
# 2                                             4.9
# 3                                             4.2
# 4                                             2.1
# ...

# %%
df_cleaned.reset_index(drop=True, inplace=True)
df_cleaned.head()
# Out:
# 0       Geography Geographic Area Name Estimate!!Households!!Total  \
# 0     0400000US06           California                    13103114
# 1  8600000US89010          ZCTA5 89010                         185
# 2  8600000US89019          ZCTA5 89019                        1114
# 3  8600000US89060          ZCTA5 89060                        4348
# 4  8600000US89061          ZCTA5 89061                        2527
#
# 0 Estimate!!Households!!Total!!Less than $10,000  \
# 0                                            4.7
# 1                                            0.0
# 2                                            1.3
# 3                                            8.6
# 4                                            4.2
#
# 0 Estimate!!Households!!Total!!$10,000 to $14,999  \
# 0                                             3.9
# 1                                             4.9
# 2                                             4.2
# 3                                             2.1
# ...

# %%
df_cleaned.drop(columns=["Geography"], inplace=True)
df_cleaned.head()
# Out:
# 0 Geographic Area Name Estimate!!Households!!Total  \
# 0           California                    13103114
# 1          ZCTA5 89010                         185
# 2          ZCTA5 89019                        1114
# 3          ZCTA5 89060                        4348
# 4          ZCTA5 89061                        2527
#
# 0 Estimate!!Households!!Total!!Less than $10,000  \
# 0                                            4.7
# 1                                            0.0
# 2                                            1.3
# 3                                            8.6
# 4                                            4.2
#
# 0 Estimate!!Households!!Total!!$10,000 to $14,999  \
# 0                                             3.9
# 1                                             4.9
# 2                                             4.2
# 3                                             2.1
# 4                                             8.0
#
# ...

# %%
df_cleaned = df_cleaned.drop(index=0)
df_cleaned.reset_index(drop=True, inplace=True)
df_cleaned.head()
# Out:
# 0 Geographic Area Name Estimate!!Households!!Total  \
# 0          ZCTA5 89010                         185
# 1          ZCTA5 89019                        1114
# 2          ZCTA5 89060                        4348
# 3          ZCTA5 89061                        2527
# 4          ZCTA5 89439                         633
#
# 0 Estimate!!Households!!Total!!Less than $10,000  \
# 0                                            0.0
# 1                                            1.3
# 2                                            8.6
# 3                                            4.2
# 4                                            2.7
#
# 0 Estimate!!Households!!Total!!$10,000 to $14,999  \
# 0                                             4.9
# 1                                             4.2
# 2                                             2.1
# 3                                             8.0
# 4                                             8.2
#
# ...

# %%
df_cleaned.rename(columns={'Geographic Area Name' : 'ZIP Code'}, inplace = True)
df_cleaned.head()
# Out:
# 0     ZIP Code Estimate!!Households!!Total  \
# 0  ZCTA5 89010                         185
# 1  ZCTA5 89019                        1114
# 2  ZCTA5 89060                        4348
# 3  ZCTA5 89061                        2527
# 4  ZCTA5 89439                         633
#
# 0 Estimate!!Households!!Total!!Less than $10,000  \
# 0                                            0.0
# 1                                            1.3
# 2                                            8.6
# 3                                            4.2
# 4                                            2.7
#
# 0 Estimate!!Households!!Total!!$10,000 to $14,999  \
# 0                                             4.9
# 1                                             4.2
# 2                                             2.1
# 3                                             8.0
# 4                                             8.2
#
# 0 Estimate!!Households!!Total!!$15,000 to $24,999  \
# ...

# %%
list(df_cleaned)
# Out:
# ['ZIP Code',
#  'Estimate!!Households!!Total',
#  'Estimate!!Households!!Total!!Less than $10,000',
#  'Estimate!!Households!!Total!!$10,000 to $14,999',
#  'Estimate!!Households!!Total!!$15,000 to $24,999',
#  'Estimate!!Households!!Total!!$25,000 to $34,999',
#  'Estimate!!Households!!Total!!$35,000 to $49,999',
#  'Estimate!!Households!!Total!!$50,000 to $74,999',
#  'Estimate!!Households!!Total!!$75,000 to $99,999',
#  'Estimate!!Households!!Total!!$100,000 to $149,999',
#  'Estimate!!Households!!Total!!$150,000 to $199,999',
#  'Estimate!!Households!!Total!!$200,000 or more',
#  'Estimate!!Households!!Median income (dollars)',
#  'Estimate!!Households!!Mean income (dollars)',
#  'Estimate!!Households!!PERCENT ALLOCATED!!Household income in the past 12 months',
#  'Estimate!!Households!!PERCENT ALLOCATED!!Family income in the past 12 months',
#  'Estimate!!Households!!PERCENT ALLOCATED!!Nonfamily income in the past 12 months',
#  'Estimate!!Families!!Total',
# ...

# %%
new_column_names = {
    'Estimate!!Households!!Total': 'Total Households',
    'Estimate!!Households!!Total!!Less than $10,000': 'Households with income < $10,000',
    'Estimate!!Households!!Total!!$10,000 to $14,999': 'Households with income $10k-$14.9k',
    'Estimate!!Households!!Total!!$15,000 to $24,999': 'Households with income $15k-$24.9k',
    'Estimate!!Households!!Total!!$25,000 to $34,999': 'Households with income $25k-$34.9k',
    'Estimate!!Households!!Total!!$35,000 to $49,999': 'Households with income $35k-$49.9k',
    'Estimate!!Households!!Total!!$50,000 to $74,999': 'Households with income $50k-$74.9k',
    'Estimate!!Households!!Total!!$75,000 to $99,999': 'Households with income $75k-$99.9k',
    'Estimate!!Households!!Total!!$100,000 to $149,999': 'Households with income $100k-$149.9k',
    'Estimate!!Households!!Total!!$150,000 to $199,999': 'Households with income $150k-$199.9k',
    'Estimate!!Households!!Total!!$200,000 or more': 'Households with income $200k+',
    'Estimate!!Households!!Median income (dollars)': 'Household Median Income',
    'Estimate!!Households!!Mean income (dollars)': 'Household Mean Income',
    'Estimate!!Households!!PERCENT ALLOCATED!!Household income in the past 12 months': 'Percent Allocated Household Income (past 12 months)',
    'Estimate!!Households!!PERCENT ALLOCATED!!Family income in the past 12 months': 'Percent Allocated Family Income (past 12 months)',
    'Estimate!!Households!!PERCENT ALLOCATED!!Nonfamily income in the past 12 months': 'Percent Allocated Nonfamily Income (past 12 months)'
}

df_cleaned.rename(columns=new_column_names, inplace=True)

list(df_cleaned)
# Out:
# ['ZIP Code',
#  'Total Households',
#  'Households with income < $10,000',
#  'Households with income $10k-$14.9k',
#  'Households with income $15k-$24.9k',
#  'Households with income $25k-$34.9k',
#  'Households with income $35k-$49.9k',
#  'Households with income $50k-$74.9k',
#  'Households with income $75k-$99.9k',
#  'Households with income $100k-$149.9k',
#  'Households with income $150k-$199.9k',
#  'Households with income $200k+',
#  'Household Median Income',
#  'Household Mean Income',
#  'Percent Allocated Household Income (past 12 months)',
#  'Percent Allocated Family Income (past 12 months)',
#  'Percent Allocated Nonfamily Income (past 12 months)',
#  'Estimate!!Families!!Total',
#  'Estimate!!Families!!Total!!Less than $10,000',
#  'Estimate!!Families!!Total!!$10,000 to $14,999',
#  'Estimate!!Families!!Total!!$15,000 to $24,999',
#  'Estimate!!Families!!Total!!$25,000 to $34,999',
#  'Estimate!!Families!!Total!!$35,000 to $49,999',
# ...

# %%
new_column_names = {
    'Estimate!!Families!!Total': 'Total Families',
    'Estimate!!Families!!Total!!Less than $10,000': 'Families with income < $10,000',
    'Estimate!!Families!!Total!!$10,000 to $14,999': 'Families with income $10k-$14.9k',
    'Estimate!!Families!!Total!!$15,000 to $24,999': 'Families with income $15k-$24.9k',
    'Estimate!!Families!!Total!!$25,000 to $34,999': 'Families with income $25k-$34.9k',
    'Estimate!!Families!!Total!!$35,000 to $49,999': 'Families with income $35k-$49.9k',
    'Estimate!!Families!!Total!!$50,000 to $74,999': 'Families with income $50k-$74.9k',
    'Estimate!!Families!!Total!!$75,000 to $99,999': 'Families with income $75k-$99.9k',
    'Estimate!!Families!!Total!!$100,000 to $149,999': 'Families with income $100k-$149.9k',
    'Estimate!!Families!!Total!!$150,000 to $199,999': 'Families with income $150k-$199.9k',
    'Estimate!!Families!!Total!!$200,000 or more': 'Families with income $200k+',
    'Estimate!!Families!!Median income (dollars)': 'Family Median Income',
    'Estimate!!Families!!Mean income (dollars)': 'Family Mean Income',
    'Estimate!!Families!!PERCENT ALLOCATED!!Household income in the past 12 months': 'Percent Allocated Family Income (12 months)',
    'Estimate!!Families!!PERCENT ALLOCATED!!Family income in the past 12 months': 'Percent Allocated Family Income (12 months)',
    'Estimate!!Families!!PERCENT ALLOCATED!!Nonfamily income in the past 12 months': 'Percent Allocated Nonfamily Income (12 months)',
    'Estimate!!Married-couple families!!Total': 'Total Married-couple Families',
    'Estimate!!Married-couple families!!Total!!Less than $10,000': 'Married-couple Families with income < $10,000',
    'Estimate!!Married-couple families!!Total!!$10,000 to $14,999': 'Married-couple Families with income $10k-$14.9k',
    'Estimate!!Married-couple families!!Total!!$15,000 to $24,999': 'Married-couple Families with income $15k-$24.9k',
    'Estimate!!Married-couple families!!Total!!$25,000 to $34,999': 'Married-couple Families with income $25k-$34.9k',
    'Estimate!!Married-couple families!!Total!!$35,000 to $49,999': 'Married-couple Families with income $35k-$49.9k',
    'Estimate!!Married-couple families!!Total!!$50,000 to $74,999': 'Married-couple Families with income $50k-$74.9k',
    'Estimate!!Married-couple families!!Total!!$75,000 to $99,999': 'Married-couple Families with income $75k-$99.9k',
    'Estimate!!Married-couple families!!Total!!$100,000 to $149,999': 'Married-couple Families with income $100k-$149.9k',
    'Estimate!!Married-couple families!!Total!!$150,000 to $199,999': 'Married-couple Families with income $150k-$199.9k',
    'Estimate!!Married-couple families!!Total!!$200,000 or more': 'Married-couple Families with income $200k+',
    'Estimate!!Married-couple families!!Median income (dollars)': 'Married-couple Family Median Income',
    'Estimate!!Married-couple families!!Mean income (dollars)': 'Married-couple Family Mean Income',
    'Estimate!!Married-couple families!!PERCENT ALLOCATED!!Household income in the past 12 months': 'Percent Allocated Married-couple Household Income',
}

df_cleaned.rename(columns=new_column_names, inplace=True)

list(df_cleaned)
# Out:
# ['ZIP Code',
#  'Total Households',
#  'Households with income < $10,000',
#  'Households with income $10k-$14.9k',
#  'Households with income $15k-$24.9k',
#  'Households with income $25k-$34.9k',
#  'Households with income $35k-$49.9k',
#  'Households with income $50k-$74.9k',
#  'Households with income $75k-$99.9k',
#  'Households with income $100k-$149.9k',
#  'Households with income $150k-$199.9k',
#  'Households with income $200k+',
#  'Household Median Income',
#  'Household Mean Income',
#  'Percent Allocated Household Income (past 12 months)',
#  'Percent Allocated Family Income (past 12 months)',
#  'Percent Allocated Nonfamily Income (past 12 months)',
#  'Total Families',
#  'Families with income < $10,000',
#  'Families with income $10k-$14.9k',
#  'Families with income $15k-$24.9k',
#  'Families with income $25k-$34.9k',
#  'Families with income $35k-$49.9k',
#  'Families with income $50k-$74.9k',
#  'Families with income $75k-$99.9k',
# ...

# %%
new_column_names = {
    'Estimate!!Married-couple families!!PERCENT ALLOCATED!!Family income in the past 12 months': 'Percent Allocated Married-couple Family Income (12 months)',
    'Estimate!!Married-couple families!!PERCENT ALLOCATED!!Nonfamily income in the past 12 months': 'Percent Allocated Married-couple Nonfamily Income (12 months)',
    'Estimate!!Nonfamily households!!Total': 'Total Nonfamily Households',
    'Estimate!!Nonfamily households!!Total!!Less than $10,000': 'Nonfamily Households with income < $10,000',
    'Estimate!!Nonfamily households!!Total!!$10,000 to $14,999': 'Nonfamily Households with income $10k-$14.9k',
    'Estimate!!Nonfamily households!!Total!!$15,000 to $24,999': 'Nonfamily Households with income $15k-$24.9k',
    'Estimate!!Nonfamily households!!Total!!$25,000 to $34,999': 'Nonfamily Households with income $25k-$34.9k',
    'Estimate!!Nonfamily households!!Total!!$35,000 to $49,999': 'Nonfamily Households with income $35k-$49.9k',
    'Estimate!!Nonfamily households!!Total!!$50,000 to $74,999': 'Nonfamily Households with income $50k-$74.9k',
    'Estimate!!Nonfamily households!!Total!!$75,000 to $99,999': 'Nonfamily Households with income $75k-$99.9k',
    'Estimate!!Nonfamily households!!Total!!$100,000 to $149,999': 'Nonfamily Households with income $100k-$149.9k',
    'Estimate!!Nonfamily households!!Total!!$150,000 to $199,999': 'Nonfamily Households with income $150k-$199.9k',
    'Estimate!!Nonfamily households!!Total!!$200,000 or more': 'Nonfamily Households with income $200k+',
    'Estimate!!Nonfamily households!!Median income (dollars)': 'Nonfamily Household Median Income',
    'Estimate!!Nonfamily households!!Mean income (dollars)': 'Nonfamily Household Mean Income',
    'Estimate!!Nonfamily households!!PERCENT ALLOCATED!!Household income in the past 12 months': 'Percent Allocated Nonfamily Household Income (12 months)',
    'Estimate!!Nonfamily households!!PERCENT ALLOCATED!!Family income in the past 12 months': 'Percent Allocated Nonfamily Family Income (12 months)',
    'Estimate!!Nonfamily households!!PERCENT ALLOCATED!!Nonfamily income in the past 12 months': 'Percent Allocated Nonfamily Nonfamily Income (12 months)',
}

df_cleaned.rename(columns=new_column_names, inplace=True)


list(df_cleaned)
# Out:
# ['ZIP Code',
#  'Total Households',
#  'Households with income < $10,000',
#  'Households with income $10k-$14.9k',
#  'Households with income $15k-$24.9k',
#  'Households with income $25k-$34.9k',
#  'Households with income $35k-$49.9k',
#  'Households with income $50k-$74.9k',
#  'Households with income $75k-$99.9k',
#  'Households with income $100k-$149.9k',
#  'Households with income $150k-$199.9k',
#  'Households with income $200k+',
#  'Household Median Income',
#  'Household Mean Income',
#  'Percent Allocated Household Income (past 12 months)',
#  'Percent Allocated Family Income (past 12 months)',
#  'Percent Allocated Nonfamily Income (past 12 months)',
#  'Total Families',
#  'Families with income < $10,000',
#  'Families with income $10k-$14.9k',
#  'Families with income $15k-$24.9k',
#  'Families with income $25k-$34.9k',
#  'Families with income $35k-$49.9k',
#  'Families with income $50k-$74.9k',
#  'Families with income $75k-$99.9k',
# ...

# %%
df_cleaned['ZIP Code'] = df_cleaned['ZIP Code'].str.extract(r'ZCTA5 (\d+)')

print(df_cleaned['ZIP Code'].head())
# Out:
# 0    89010
# 1    89019
# 2    89060
# 3    89061
# 4    89439
# Name: ZIP Code, dtype: object

# %%
df_cleaned['ZIP Code'] = pd.to_numeric(df_cleaned['ZIP Code'], errors='coerce')
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1769 entries, 0 to 1768
# Data columns (total 65 columns):
#  #   Column                                                         Non-Null Count  Dtype
# ---  ------                                                         --------------  -----
#  0   ZIP Code                                                       1769 non-null   int64
#  1   Total Households                                               1769 non-null   object
#  2   Households with income < $10,000                               1769 non-null   object
#  3   Households with income $10k-$14.9k                             1769 non-null   object
#  4   Households with income $15k-$24.9k                             1769 non-null   object
#  5   Households with income $25k-$34.9k                             1769 non-null   object
#  6   Households with income $35k-$49.9k                             1769 non-null   object
# ...

# %%
relevant_columns = [
    'ZIP Code',
    'Household Median Income',
    'Household Mean Income',
    'Family Median Income',
    'Family Mean Income',
    'Married-couple Family Median Income',
    'Married-couple Family Mean Income',
    'Nonfamily Household Median Income',
    'Nonfamily Household Mean Income'
]

df_final = df_cleaned[relevant_columns]


df_final
# Out:
# 0     ZIP Code Household Median Income Household Mean Income  \
# 0        89010                   32847                 53109
# 1        89019                   56765                 86818
# 2        89060                   45833                 56469
# 3        89061                   56865                 62940
# 4        89439                   60547                 89705
# ...        ...                     ...                   ...
# 1764     96148                   81833                106323
# 1765     96150                   62541                 95949
# 1766     96155                       -                     -
# 1767     96161                  100205                148847
# 1768     97635                       -                 73435
#
# 0    Family Median Income Family Mean Income  \
# 0                   44750              66807
# 1                   89558             131125
# 2                   52552              60592
# 3                   61148              69431
# ...

# %%
print(df_final['Married-couple Family Mean Income'].unique())
# Out:
# ['N' '66307' '63438' '78998' '63774' '122509' '72324' '66925' '67492'
#  '83517' '107159' '76890' '-' '66860' '92778' '102369' '73437' '78702'
#  '82499' '112404' '127778' '92526' '104043' '95481' '117417' '77560'
#  '83446' '92809' '103715' '110654' '104055' '96634' '81853' '100839'
#  '92930' '98811' '86717' '82503' '78045' '111694' '104618' '98657' '91462'
#  '95397' '82968' '101966' '118007' '117927' '102044' '75738' '103609'
#  '135709' '108192' '123526' '77029' '113955' '137894' '130505' '124851'
#  '100283' '87829' '71569' '83713' '137076' '88665' '79220' '79282' '87123'
#  '92649' '80557' '110222' '102302' '104342' '106865' '69542' '75854'
#  '103136' '91894' '109785' '84897' '100873' '103861' '99480' '144816'
#  '132381' '94169' '120592' '82237' '108569' '165350' '100476' '81019'
#  '89230' '105425' '100061' '65413' '89878' '91269' '75479' '77869' '95612'
#  '71225' '95528' '107323' '148046' '105385' '109125' '185092' '133882'
# ...

# %%
duplicates = df_final[df_final.duplicated()]
duplicates
# Out:
# Empty DataFrame
# Columns: [ZIP Code, Household Median Income, Household Mean Income, Family Median Income, Family Mean Income, Married-couple Family Median Income, Married-couple Family Mean Income, Nonfamily Household Median Income, Nonfamily Household Mean Income]
# Index: []

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1769 entries, 0 to 1768
# Data columns (total 9 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   ZIP Code                             1769 non-null   int64
#  1   Household Median Income              1769 non-null   object
#  2   Household Mean Income                1769 non-null   object
#  3   Family Median Income                 1769 non-null   object
#  4   Family Mean Income                   1769 non-null   object
#  5   Married-couple Family Median Income  1769 non-null   object
#  6   Married-couple Family Mean Income    1769 non-null   object
#  7   Nonfamily Household Median Income    1769 non-null   object
#  8   Nonfamily Household Mean Income      1769 non-null   object
# dtypes: int64(1), object(8)
# memory usage: 124.5+ KB

# %%
income_columns = [
    'Household Median Income',
    'Household Mean Income',
    'Family Median Income',
    'Family Mean Income',
    'Married-couple Family Median Income',
    'Married-couple Family Mean Income',
    'Nonfamily Household Median Income',
    'Nonfamily Household Mean Income'
]

df_final[income_columns] = df_final[income_columns].apply(pd.to_numeric, errors='coerce')

df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1769 entries, 0 to 1768
# Data columns (total 9 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   ZIP Code                             1769 non-null   int64
#  1   Household Median Income              1600 non-null   float64
#  2   Household Mean Income                1676 non-null   float64
#  3   Family Median Income                 1553 non-null   float64
#  4   Family Mean Income                   1637 non-null   float64
#  5   Married-couple Family Median Income  1523 non-null   float64
#  6   Married-couple Family Mean Income    132 non-null    float64
#  7   Nonfamily Household Median Income    1474 non-null   float64
#  8   Nonfamily Household Mean Income      1598 non-null   float64
# dtypes: float64(8), int64(1)
# memory usage: 124.5 KB
# ...

# %%
df_final.head()
# Out:
# 0  ZIP Code  Household Median Income  Household Mean Income  \
# 0     89010                  32847.0                53109.0
# 1     89019                  56765.0                86818.0
# 2     89060                  45833.0                56469.0
# 3     89061                  56865.0                62940.0
# 4     89439                  60547.0                89705.0
#
# 0  Family Median Income  Family Mean Income  \
# 0               44750.0             66807.0
# 1               89558.0            131125.0
# 2               52552.0             60592.0
# 3               61148.0             69431.0
# 4               81875.0            113306.0
#
# 0  Married-couple Family Median Income  Married-couple Family Mean Income  \
# 0                              67813.0                                NaN
# 1                                  NaN                                NaN
# 2                              53488.0                                NaN
# ...
