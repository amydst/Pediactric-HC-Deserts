# %%
import pandas as pd

# %%
Path = 'kids_per_code.csv'

# %%
df_kids = pd.read_csv(Path)

# %%
df_kids
# Out:
#       ZIP Code  Population Under 18 years (Selected)  Total Population  \
# 0        89010                                    71               461
# 1        89019                                   146              2312
# 2        89060                                  1917             12198
# 3        89061                                   971              7529
# 4        89439                                   192              1639
# ...        ...                                   ...               ...
# 1803     96148                                    69               630
# 1804     96150                                  4779             29457
# 1805     96155                                     0                 0
# 1806     96161                                  4062             19146
# 1807     97635                                   123               345
#
#       Population Under 5 years  Population 5 to 9 years  \
# 0                           20                       28
# ...

# %%
list(df_kids)
# Out:
# ['ZIP Code',
#  'Population Under 18 years (Selected)',
#  'Total Population',
#  'Population Under 5 years',
#  'Population 5 to 9 years',
#  'Population 10 to 14 years',
#  'Population 15 to 19 years',
#  'Percent Population Under 5 years',
#  'Percent Population 5 to 9 years',
#  'Percent Population 10 to 14 years',
#  'Percent Population Under 18 years (Selected)',
#  'Male Population Under 5 years',
#  'Male Population 5 to 9 years',
#  'Male Population 10 to 14 years',
#  'Female Population Under 5 years',
#  'Female Population 5 to 9 years',
#  'Female Population 10 to 14 years',
#  'Female Population Under 18 years (Selected)']

# %%
columns_to_drop = [
    'Population Under 5 years',
    'Population 5 to 9 years',
    'Population 10 to 14 years',
    'Population 15 to 19 years',
    'Percent Population Under 5 years',
    'Percent Population 5 to 9 years',
    'Percent Population 10 to 14 years',
    'Male Population Under 5 years',
    'Male Population 5 to 9 years',
    'Male Population 10 to 14 years',
    'Female Population Under 5 years',
    'Female Population 5 to 9 years',
    'Female Population 10 to 14 years',
]
df_kids= df_kids.drop(columns=columns_to_drop)

# %%
df_kids
# Out:
#       ZIP Code  Population Under 18 years (Selected)  Total Population  \
# 0        89010                                    71               461
# 1        89019                                   146              2312
# 2        89060                                  1917             12198
# 3        89061                                   971              7529
# 4        89439                                   192              1639
# ...        ...                                   ...               ...
# 1803     96148                                    69               630
# 1804     96150                                  4779             29457
# 1805     96155                                     0                 0
# 1806     96161                                  4062             19146
# 1807     97635                                   123               345
#
#       Percent Population Under 18 years (Selected)  \
# 0                                             15.4
# ...

# %%
df_kids['Male Population Under 18 years (Selected)'] = df_kids['Population Under 18 years (Selected)'] - df_kids['Female Population Under 18 years (Selected)']
df_kids
# Out:
#       ZIP Code  Population Under 18 years (Selected)  Total Population  \
# 0        89010                                    71               461
# 1        89019                                   146              2312
# 2        89060                                  1917             12198
# 3        89061                                   971              7529
# 4        89439                                   192              1639
# ...        ...                                   ...               ...
# 1803     96148                                    69               630
# 1804     96150                                  4779             29457
# 1805     96155                                     0                 0
# 1806     96161                                  4062             19146
# 1807     97635                                   123               345
#
#       Percent Population Under 18 years (Selected)  \
# 0                                             15.4
# ...

# %%
df_kids.rename(columns = {
    'Population Under 18 years (Selected)' : 'Population Under 18 years',
    'Percent Population Under 18 years (Selected)' : 'Percent Population Under 18 years',
    'Female Population Under 18 years (Selected)' : 'Female Population Under 18 years',
    'Male Population Under 18 years (Selected)' : 'Male Population Under 18 years'
}, inplace = True)
df_kids.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1808 entries, 0 to 1807
# Data columns (total 6 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   ZIP Code                           1808 non-null   int64
#  1   Population Under 18 years          1808 non-null   int64
#  2   Total Population                   1808 non-null   int64
#  3   Percent Population Under 18 years  1771 non-null   float64
#  4   Female Population Under 18 years   1808 non-null   int64
#  5   Male Population Under 18 years     1808 non-null   int64
# dtypes: float64(1), int64(5)
# memory usage: 84.9 KB

# %%
df_kids['ZIP Code'] = df_kids['ZIP Code'].astype('string')

# %%
df_kids.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1808 entries, 0 to 1807
# Data columns (total 6 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   ZIP Code                           1808 non-null   string
#  1   Population Under 18 years          1808 non-null   int64
#  2   Total Population                   1808 non-null   int64
#  3   Percent Population Under 18 years  1771 non-null   float64
#  4   Female Population Under 18 years   1808 non-null   int64
#  5   Male Population Under 18 years     1808 non-null   int64
# dtypes: float64(1), int64(4), string(1)
# memory usage: 84.9 KB

# %%
Path2 = 'pop_density_per_zip.csv'

# %%
df_populat = pd.read_csv(Path2)

# %%
df_populat
# Out:
#       Zipcode Land Area sq meters Water Area sq meters  Land Area sq miles  \
# 0       89060       1,164,029,185               83,993             449.434
# 1       89061         165,855,694               10,631              64.037
# 2       89439          42,115,079              336,966              16.261
# 3       90001           8,495,419                    0               3.280
# 4       90002           7,750,658                    0               2.993
# ...       ...                 ...                  ...                 ...
# 1754    96148           5,411,110                    0               2.089
# 1755    96150         422,599,296           14,431,182             163.167
# 1756    96155          97,744,600               76,028              37.739
# 1757    96161         680,238,466            9,131,164             262.642
# 1758    97635         135,078,015              153,823              52.154
#
#       Water Area sq miles   Latitude     Longitude  Population  \
# ...

# %%
df_populat = df_populat[['Zipcode', 'Population Density per sq mile']]
df_populat
# Out:
#       Zipcode  Population Density per sq mile
# 0       89060                       23.789922
# 1       89061                       86.465637
# 2       89439                       76.502060
# 3       90001                    17979.878049
# 4       90002                    17842.298697
# ...       ...                             ...
# 1754    96148                      325.035902
# 1755    96150                      186.122194
# 1756    96155                        0.000000
# 1757    96161                       71.511792
# 1758    97635                        3.144533
#
# [1759 rows x 2 columns]

# %%
df_populat.rename(columns = {"Zipcode" : "ZIP Code"}, inplace = True)
# Out:
# /var/folders/9g/q_vt4mks1rz6myydd0n5jcwc0000gn/T/ipykernel_15648/1269206251.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_populat.rename(columns = {"Zipcode" : "ZIP Code"}, inplace = True)

# %%
df_populat
# Out:
#       ZIP Code  Population Density per sq mile
# 0        89060                       23.789922
# 1        89061                       86.465637
# 2        89439                       76.502060
# 3        90001                    17979.878049
# 4        90002                    17842.298697
# ...        ...                             ...
# 1754     96148                      325.035902
# 1755     96150                      186.122194
# 1756     96155                        0.000000
# 1757     96161                       71.511792
# 1758     97635                        3.144533
#
# [1759 rows x 2 columns]

# %%
df_populat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1759 entries, 0 to 1758
# Data columns (total 2 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   ZIP Code                        1759 non-null   int64
#  1   Population Density per sq mile  1759 non-null   float64
# dtypes: float64(1), int64(1)
# memory usage: 27.6 KB

# %%
df_populat['ZIP Code'] = df_populat['ZIP Code'].astype('string')
df_populat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1759 entries, 0 to 1758
# Data columns (total 2 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   ZIP Code                        1759 non-null   string
#  1   Population Density per sq mile  1759 non-null   float64
# dtypes: float64(1), string(1)
# memory usage: 27.6 KB
# /var/folders/9g/q_vt4mks1rz6myydd0n5jcwc0000gn/T/ipykernel_15648/969823593.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_populat['ZIP Code'] = df_populat['ZIP Code'].astype('string')

# %%
kids_popul = pd.merge(df_kids, df_populat, on='ZIP Code', how='outer')
kids_popul
# Out:
#      ZIP Code  Population Under 18 years  Total Population  \
# 0       89010                         71               461
# 1       89019                        146              2312
# 2       89060                       1917             12198
# 3       89061                        971              7529
# 4       89439                        192              1639
# ...       ...                        ...               ...
# 1803    96148                         69               630
# 1804    96150                       4779             29457
# 1805    96155                          0                 0
# 1806    96161                       4062             19146
# 1807    97635                        123               345
#
#       Percent Population Under 18 years  Female Population Under 18 years  \
# 0                                  15.4                                36
# 1                                   6.3                               109
# ...

# %%
kids_popul.to_csv("Population_table_for_sql.csv", index = False)
