# %%
import pandas as pd

# %%
Path = "kids_per_zip.csv"

# %%
df = pd.read_csv(Path)

# %%
df.head()
# Out:
#            GEO_ID                  NAME                     S0101_C01_001E  \
# 0       Geography  Geographic Area Name  Estimate!!Total!!Total population
# 1  860Z200US89010           ZCTA5 89010                                461
# 2  860Z200US89019           ZCTA5 89019                               2312
# 3  860Z200US89060           ZCTA5 89060                              12198
# 4  860Z200US89061           ZCTA5 89061                               7529
#
#                              S0101_C01_001M  \
# 0  Margin of Error!!Total!!Total population
# 1                                       152
# 2                                       618
# 3                                      1103
# 4                                       880
#
#                                       S0101_C01_002E  \
# 0  Estimate!!Total!!Total population!!AGE!!Under ...
# 1                                                 20
# 2                                                 56
# ...

# %%
df.rename(columns={'NAME':'zip'}, inplace = True)
df.head()
# Out:
#            GEO_ID                   zip                     S0101_C01_001E  \
# 0       Geography  Geographic Area Name  Estimate!!Total!!Total population
# 1  860Z200US89010           ZCTA5 89010                                461
# 2  860Z200US89019           ZCTA5 89019                               2312
# 3  860Z200US89060           ZCTA5 89060                              12198
# 4  860Z200US89061           ZCTA5 89061                               7529
#
#                              S0101_C01_001M  \
# 0  Margin of Error!!Total!!Total population
# 1                                       152
# 2                                       618
# 3                                      1103
# 4                                       880
#
#                                       S0101_C01_002E  \
# 0  Estimate!!Total!!Total population!!AGE!!Under ...
# 1                                                 20
# 2                                                 56
# ...

# %%
list(df)
# Out:
# ['GEO_ID',
#  'zip',
#  'S0101_C01_001E',
#  'S0101_C01_001M',
#  'S0101_C01_002E',
#  'S0101_C01_002M',
#  'S0101_C01_003E',
#  'S0101_C01_003M',
#  'S0101_C01_004E',
#  'S0101_C01_004M',
#  'S0101_C01_005E',
#  'S0101_C01_005M',
#  'S0101_C01_006E',
#  'S0101_C01_006M',
#  'S0101_C01_007E',
#  'S0101_C01_007M',
#  'S0101_C01_008E',
#  'S0101_C01_008M',
#  'S0101_C01_009E',
#  'S0101_C01_009M',
#  'S0101_C01_010E',
#  'S0101_C01_010M',
#  'S0101_C01_011E',
#  'S0101_C01_011M',
#  'S0101_C01_012E',
#  'S0101_C01_012M',
#  'S0101_C01_013E',
#  'S0101_C01_013M',
#  'S0101_C01_014E',
#  'S0101_C01_014M',
#  'S0101_C01_015E',
#  'S0101_C01_015M',
#  'S0101_C01_016E',
#  'S0101_C01_016M',
#  'S0101_C01_017E',
#  'S0101_C01_017M',
#  'S0101_C01_018E',
#  'S0101_C01_018M',
#  'S0101_C01_019E',
#  'S0101_C01_019M',
#  'S0101_C01_020E',
#  'S0101_C01_020M',
#  'S0101_C01_021E',
#  'S0101_C01_021M',
#  'S0101_C01_022E',
#  'S0101_C01_022M',
#  'S0101_C01_023E',
#  'S0101_C01_023M',
# ...

# %%
df = df.loc[:, ~df.columns.str.contains('M|Unnamed')]
list(df)
# Out:
# ['GEO_ID',
#  'zip',
#  'S0101_C01_001E',
#  'S0101_C01_002E',
#  'S0101_C01_003E',
#  'S0101_C01_004E',
#  'S0101_C01_005E',
#  'S0101_C01_006E',
#  'S0101_C01_007E',
#  'S0101_C01_008E',
#  'S0101_C01_009E',
#  'S0101_C01_010E',
#  'S0101_C01_011E',
#  'S0101_C01_012E',
#  'S0101_C01_013E',
#  'S0101_C01_014E',
#  'S0101_C01_015E',
#  'S0101_C01_016E',
#  'S0101_C01_017E',
#  'S0101_C01_018E',
#  'S0101_C01_019E',
#  'S0101_C01_020E',
#  'S0101_C01_021E',
#  'S0101_C01_022E',
#  'S0101_C01_023E',
#  'S0101_C01_024E',
#  'S0101_C01_025E',
#  'S0101_C01_026E',
#  'S0101_C01_027E',
#  'S0101_C01_028E',
#  'S0101_C01_029E',
#  'S0101_C01_030E',
#  'S0101_C01_031E',
#  'S0101_C01_032E',
#  'S0101_C01_033E',
#  'S0101_C01_034E',
#  'S0101_C01_035E',
#  'S0101_C01_036E',
#  'S0101_C01_037E',
#  'S0101_C01_038E',
#  'S0101_C02_001E',
#  'S0101_C02_002E',
#  'S0101_C02_003E',
#  'S0101_C02_004E',
#  'S0101_C02_005E',
#  'S0101_C02_006E',
#  'S0101_C02_007E',
#  'S0101_C02_008E',
# ...

# %%
df.columns = df.iloc[0]
df = df.drop(index=0)
df.head()
# Out:
# 0       Geography Geographic Area Name Estimate!!Total!!Total population  \
# 1  860Z200US89010          ZCTA5 89010                               461
# 2  860Z200US89019          ZCTA5 89019                              2312
# 3  860Z200US89060          ZCTA5 89060                             12198
# 4  860Z200US89061          ZCTA5 89061                              7529
# 5  860Z200US89439          ZCTA5 89439                              1639
#
# 0 Estimate!!Total!!Total population!!AGE!!Under 5 years  \
# 1                                                 20
# 2                                                 56
# 3                                                509
# 4                                                 69
# 5                                                 42
#
# 0 Estimate!!Total!!Total population!!AGE!!5 to 9 years  \
# 1                                                 28
# 2                                                 31
# ...

# %%
df.drop('Geography', axis=1, inplace=True)
df.head()
# Out:
# 0 Geographic Area Name Estimate!!Total!!Total population  \
# 1          ZCTA5 89010                               461
# 2          ZCTA5 89019                              2312
# 3          ZCTA5 89060                             12198
# 4          ZCTA5 89061                              7529
# 5          ZCTA5 89439                              1639
#
# 0 Estimate!!Total!!Total population!!AGE!!Under 5 years  \
# 1                                                 20
# 2                                                 56
# 3                                                509
# 4                                                 69
# 5                                                 42
#
# 0 Estimate!!Total!!Total population!!AGE!!5 to 9 years  \
# 1                                                 28
# 2                                                 31
# 3                                                662
# 4                                                411
# ...

# %%
df.rename(columns = {'Geographic Area Name': "ZIP Code"}, inplace = True)
df.head()
# Out:
# 0     ZIP Code Estimate!!Total!!Total population  \
# 1  ZCTA5 89010                               461
# 2  ZCTA5 89019                              2312
# 3  ZCTA5 89060                             12198
# 4  ZCTA5 89061                              7529
# 5  ZCTA5 89439                              1639
#
# 0 Estimate!!Total!!Total population!!AGE!!Under 5 years  \
# 1                                                 20
# 2                                                 56
# 3                                                509
# 4                                                 69
# 5                                                 42
#
# 0 Estimate!!Total!!Total population!!AGE!!5 to 9 years  \
# 1                                                 28
# 2                                                 31
# 3                                                662
# 4                                                411
# 5                                                111
#
# ...

# %%
df['ZIP Code'] = df['ZIP Code'].str.split().str[1]
df['ZIP Code']
# Out:
# 1       89010
# 2       89019
# 3       89060
# 4       89061
# 5       89439
#         ...
# 1804    96148
# 1805    96150
# 1806    96155
# 1807    96161
# 1808    97635
# Name: ZIP Code, Length: 1808, dtype: object

# %%
df['ZIP Code'] = df['ZIP Code'].astype(int)
df['ZIP Code'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 1808 entries, 1 to 1808
# Series name: ZIP Code
# Non-Null Count  Dtype
# --------------  -----
# 1808 non-null   int64
# dtypes: int64(1)
# memory usage: 14.3 KB

# %%
list(df)
# Out:
# ['ZIP Code',
#  'Estimate!!Total!!Total population',
#  'Estimate!!Total!!Total population!!AGE!!Under 5 years',
#  'Estimate!!Total!!Total population!!AGE!!5 to 9 years',
#  'Estimate!!Total!!Total population!!AGE!!10 to 14 years',
#  'Estimate!!Total!!Total population!!AGE!!15 to 19 years',
#  'Estimate!!Total!!Total population!!AGE!!20 to 24 years',
#  'Estimate!!Total!!Total population!!AGE!!25 to 29 years',
#  'Estimate!!Total!!Total population!!AGE!!30 to 34 years',
#  'Estimate!!Total!!Total population!!AGE!!35 to 39 years',
#  'Estimate!!Total!!Total population!!AGE!!40 to 44 years',
#  'Estimate!!Total!!Total population!!AGE!!45 to 49 years',
#  'Estimate!!Total!!Total population!!AGE!!50 to 54 years',
#  'Estimate!!Total!!Total population!!AGE!!55 to 59 years',
#  'Estimate!!Total!!Total population!!AGE!!60 to 64 years',
#  'Estimate!!Total!!Total population!!AGE!!65 to 69 years',
#  'Estimate!!Total!!Total population!!AGE!!70 to 74 years',
# ...

# %%
df = df.rename(columns={
    'Estimate!!Total!!Total population': 'Total Population',
    'Estimate!!Total!!Total population!!AGE!!Under 5 years': 'Population Under 5 years',
    'Estimate!!Total!!Total population!!AGE!!5 to 9 years': 'Population 5 to 9 years',
    'Estimate!!Total!!Total population!!AGE!!10 to 14 years': 'Population 10 to 14 years',
    'Estimate!!Total!!Total population!!AGE!!15 to 19 years': 'Population 15 to 19 years',
    'Estimate!!Total!!Total population!!AGE!!20 to 24 years': 'Population 20 to 24 years',
    'Estimate!!Total!!Total population!!AGE!!25 to 29 years': 'Population 25 to 29 years',
    'Estimate!!Total!!Total population!!AGE!!30 to 34 years': 'Population 30 to 34 years',
    'Estimate!!Total!!Total population!!AGE!!35 to 39 years': 'Population 35 to 39 years',
    'Estimate!!Total!!Total population!!AGE!!40 to 44 years': 'Population 40 to 44 years',
    'Estimate!!Total!!Total population!!AGE!!45 to 49 years': 'Population 45 to 49 years',
    'Estimate!!Total!!Total population!!AGE!!50 to 54 years': 'Population 50 to 54 years',
    'Estimate!!Total!!Total population!!AGE!!55 to 59 years': 'Population 55 to 59 years',
    'Estimate!!Total!!Total population!!AGE!!60 to 64 years': 'Population 60 to 64 years',
    'Estimate!!Total!!Total population!!AGE!!65 to 69 years': 'Population 65 to 69 years',
    'Estimate!!Total!!Total population!!AGE!!70 to 74 years': 'Population 70 to 74 years',
    'Estimate!!Total!!Total population!!AGE!!75 to 79 years': 'Population 75 to 79 years',
    'Estimate!!Total!!Total population!!AGE!!80 to 84 years': 'Population 80 to 84 years',
    'Estimate!!Total!!Total population!!AGE!!85 years and over': 'Population 85+ years',
    'Estimate!!Total!!Total population!!SELECTED AGE CATEGORIES!!5 to 14 years': 'Population 5 to 14 years (Selected)',
    'Estimate!!Total!!Total population!!SELECTED AGE CATEGORIES!!15 to 17 years': 'Population 15 to 17 years (Selected)',
    'Estimate!!Total!!Total population!!SELECTED AGE CATEGORIES!!Under 18 years': 'Population Under 18 years (Selected)',
    'Estimate!!Total!!Total population!!SELECTED AGE CATEGORIES!!18 to 24 years': 'Population 18 to 24 years (Selected)',
    'Estimate!!Total!!Total population!!SELECTED AGE CATEGORIES!!15 to 44 years': 'Population 15 to 44 years (Selected)',
    'Estimate!!Total!!Total population!!SELECTED AGE CATEGORIES!!16 years and over': 'Population 16+ years (Selected)',
    'Estimate!!Total!!Total population!!SELECTED AGE CATEGORIES!!18 years and over': 'Population 18+ years (Selected)',
    'Estimate!!Total!!Total population!!SELECTED AGE CATEGORIES!!21 years and over': 'Population 21+ years (Selected)',
    'Estimate!!Total!!Total population!!SELECTED AGE CATEGORIES!!60 years and over': 'Population 60+ years (Selected)',
    'Estimate!!Total!!Total population!!SELECTED AGE CATEGORIES!!62 years and over': 'Population 62+ years (Selected)',
    'Estimate!!Total!!Total population!!SELECTED AGE CATEGORIES!!65 years and over': 'Population 65+ years (Selected)',
    'Estimate!!Total!!Total population!!SELECTED AGE CATEGORIES!!75 years and over': 'Population 75+ years (Selected)'
})
list(df)
# Out:
# ['ZIP Code',
#  'Total Population',
#  'Population Under 5 years',
#  'Population 5 to 9 years',
#  'Population 10 to 14 years',
#  'Population 15 to 19 years',
#  'Population 20 to 24 years',
#  'Population 25 to 29 years',
#  'Population 30 to 34 years',
#  'Population 35 to 39 years',
#  'Population 40 to 44 years',
#  'Population 45 to 49 years',
#  'Population 50 to 54 years',
#  'Population 55 to 59 years',
#  'Population 60 to 64 years',
#  'Population 65 to 69 years',
#  'Population 70 to 74 years',
#  'Population 75 to 79 years',
#  'Population 80 to 84 years',
#  'Population 85+ years',
#  'Population 5 to 14 years (Selected)',
#  'Population 15 to 17 years (Selected)',
#  'Population Under 18 years (Selected)',
#  'Population 18 to 24 years (Selected)',
#  'Population 15 to 44 years (Selected)',
#  'Population 16+ years (Selected)',
#  'Population 18+ years (Selected)',
#  'Population 21+ years (Selected)',
#  'Population 60+ years (Selected)',
# ...

# %%
df = df.rename(columns={
    'Estimate!!Total!!Total population!!SUMMARY INDICATORS!!Median age (years)': 'Median Age (Total)',
    'Estimate!!Total!!Total population!!SUMMARY INDICATORS!!Sex ratio (males per 100 females)': 'Sex Ratio (Total)',
    'Estimate!!Total!!Total population!!SUMMARY INDICATORS!!Age dependency ratio': 'Age Dependency Ratio (Total)',
    'Estimate!!Total!!Total population!!SUMMARY INDICATORS!!Old-age dependency ratio': 'Old-age Dependency Ratio (Total)',
    'Estimate!!Total!!Total population!!SUMMARY INDICATORS!!Child dependency ratio': 'Child Dependency Ratio (Total)',
    'Estimate!!Total!!Total population!!PERCENT ALLOCATED!!Sex': 'Percent Allocated by Sex',
    'Estimate!!Total!!Total population!!PERCENT ALLOCATED!!Age': 'Percent Allocated by Age',
    'Estimate!!Percent!!Total population': 'Percent Total Population',
    'Estimate!!Percent!!Total population!!AGE!!Under 5 years': 'Percent Population Under 5 years',
    'Estimate!!Percent!!Total population!!AGE!!5 to 9 years': 'Percent Population 5 to 9 years',
    'Estimate!!Percent!!Total population!!AGE!!10 to 14 years': 'Percent Population 10 to 14 years',
    'Estimate!!Percent!!Total population!!AGE!!15 to 19 years': 'Percent Population 15 to 19 years',
    'Estimate!!Percent!!Total population!!AGE!!20 to 24 years': 'Percent Population 20 to 24 years',
    'Estimate!!Percent!!Total population!!AGE!!25 to 29 years': 'Percent Population 25 to 29 years',
    'Estimate!!Percent!!Total population!!AGE!!30 to 34 years': 'Percent Population 30 to 34 years',
    'Estimate!!Percent!!Total population!!AGE!!35 to 39 years': 'Percent Population 35 to 39 years',
    'Estimate!!Percent!!Total population!!AGE!!40 to 44 years': 'Percent Population 40 to 44 years',
    'Estimate!!Percent!!Total population!!AGE!!45 to 49 years': 'Percent Population 45 to 49 years',
    'Estimate!!Percent!!Total population!!AGE!!50 to 54 years': 'Percent Population 50 to 54 years',
    'Estimate!!Percent!!Total population!!AGE!!55 to 59 years': 'Percent Population 55 to 59 years',
    'Estimate!!Percent!!Total population!!AGE!!60 to 64 years': 'Percent Population 60 to 64 years',
    'Estimate!!Percent!!Total population!!AGE!!65 to 69 years': 'Percent Population 65 to 69 years',
    'Estimate!!Percent!!Total population!!AGE!!70 to 74 years': 'Percent Population 70 to 74 years',
    'Estimate!!Percent!!Total population!!AGE!!75 to 79 years': 'Percent Population 75 to 79 years',
    'Estimate!!Percent!!Total population!!AGE!!80 to 84 years': 'Percent Population 80 to 84 years',
    'Estimate!!Percent!!Total population!!AGE!!85 years and over': 'Percent Population 85+ years',
    'Estimate!!Percent!!Total population!!SELECTED AGE CATEGORIES!!5 to 14 years': 'Percent Population 5 to 14 years (Selected)',
    'Estimate!!Percent!!Total population!!SELECTED AGE CATEGORIES!!15 to 17 years': 'Percent Population 15 to 17 years (Selected)',
    'Estimate!!Percent!!Total population!!SELECTED AGE CATEGORIES!!Under 18 years': 'Percent Population Under 18 years (Selected)',
    'Estimate!!Percent!!Total population!!SELECTED AGE CATEGORIES!!18 to 24 years': 'Percent Population 18 to 24 years (Selected)',
    'Estimate!!Percent!!Total population!!SELECTED AGE CATEGORIES!!15 to 44 years': 'Percent Population 15 to 44 years (Selected)',
    'Estimate!!Percent!!Total population!!SELECTED AGE CATEGORIES!!16 years and over': 'Percent Population 16+ years (Selected)',
    'Estimate!!Percent!!Total population!!SELECTED AGE CATEGORIES!!18 years and over': 'Percent Population 18+ years (Selected)',
    'Estimate!!Percent!!Total population!!SELECTED AGE CATEGORIES!!21 years and over': 'Percent Population 21+ years (Selected)',
    'Estimate!!Percent!!Total population!!SELECTED AGE CATEGORIES!!60 years and over': 'Percent Population 60+ years (Selected)',
    'Estimate!!Percent!!Total population!!SELECTED AGE CATEGORIES!!62 years and over': 'Percent Population 62+ years (Selected)',
    'Estimate!!Percent!!Total population!!SELECTED AGE CATEGORIES!!65 years and over': 'Percent Population 65+ years (Selected)',
    'Estimate!!Percent!!Total population!!SELECTED AGE CATEGORIES!!75 years and over': 'Percent Population 75+ years (Selected)',
    'Estimate!!Percent!!Total population!!SUMMARY INDICATORS!!Median age (years)': 'Median Age (Percent)',
    'Estimate!!Percent!!Total population!!SUMMARY INDICATORS!!Sex ratio (males per 100 females)': 'Sex Ratio (Percent)',
    'Estimate!!Percent!!Total population!!SUMMARY INDICATORS!!Age dependency ratio': 'Age Dependency Ratio (Percent)',
    'Estimate!!Percent!!Total population!!SUMMARY INDICATORS!!Old-age dependency ratio': 'Old-age Dependency Ratio (Percent)',
    'Estimate!!Percent!!Total population!!SUMMARY INDICATORS!!Child dependency ratio': 'Child Dependency Ratio (Percent)',
    'Estimate!!Percent!!Total population!!PERCENT ALLOCATED!!Sex': 'Percent Allocated by Sex (Percent)',
    'Estimate!!Percent!!Total population!!PERCENT ALLOCATED!!Age': 'Percent Allocated by Age (Percent)',
    'Estimate!!Male!!Total population': 'Male Total Population',
    'Estimate!!Male!!Total population!!AGE!!Under 5 years': 'Male Population Under 5 years',
    'Estimate!!Male!!Total population!!AGE!!5 to 9 years': 'Male Population 5 to 9 years',
    'Estimate!!Male!!Total population!!AGE!!10 to 14 years': 'Male Population 10 to 14 years',
    'Estimate!!Male!!Total population!!AGE!!15 to 19 years': 'Male Population 15 to 19 years',
    'Estimate!!Male!!Total population!!AGE!!20 to 24 years': 'Male Population 20 to 24 years',
    'Estimate!!Male!!Total population!!AGE!!25 to 29 years': 'Male Population 25 to 29 years',
    'Estimate!!Male!!Total population!!AGE!!30 to 34 years': 'Male Population 30 to 34 years',
    'Estimate!!Male!!Total population!!AGE!!35 to 39 years': 'Male Population 35 to 39 years',
    'Estimate!!Male!!Total population!!AGE!!40 to 44 years': 'Male Population 40 to 44 years',
    'Estimate!!Male!!Total population!!AGE!!45 to 49 years': 'Male Population 45 to 49 years',
    'Estimate!!Male!!Total population!!AGE!!50 to 54 years': 'Male Population 50 to 54 years',
    'Estimate!!Male!!Total population!!AGE!!55 to 59 years': 'Male Population 55 to 59 years',
    'Estimate!!Male!!Total population!!AGE!!60 to 64 years': 'Male Population 60 to 64 years',
    'Estimate!!Male!!Total population!!AGE!!65 to 69 years': 'Male Population 65 to 69 years',
    'Estimate!!Male!!Total population!!AGE!!70 to 74 years': 'Male Population 70 to 74 years',
    'Estimate!!Male!!Total population!!AGE!!75 to 79 years': 'Male Population 75 to 79 years',
    'Estimate!!Male!!Total population!!AGE!!80 to 84 years': 'Male Population 80 to 84 years',
    'Estimate!!Male!!Total population!!AGE!!85 years and over': 'Male Population 85+ years'
})
list(df)
# Out:
# ['ZIP Code',
#  'Total Population',
#  'Population Under 5 years',
#  'Population 5 to 9 years',
#  'Population 10 to 14 years',
#  'Population 15 to 19 years',
#  'Population 20 to 24 years',
#  'Population 25 to 29 years',
#  'Population 30 to 34 years',
#  'Population 35 to 39 years',
#  'Population 40 to 44 years',
#  'Population 45 to 49 years',
#  'Population 50 to 54 years',
#  'Population 55 to 59 years',
#  'Population 60 to 64 years',
#  'Population 65 to 69 years',
#  'Population 70 to 74 years',
#  'Population 75 to 79 years',
#  'Population 80 to 84 years',
#  'Population 85+ years',
#  'Population 5 to 14 years (Selected)',
#  'Population 15 to 17 years (Selected)',
#  'Population Under 18 years (Selected)',
#  'Population 18 to 24 years (Selected)',
#  'Population 15 to 44 years (Selected)',
#  'Population 16+ years (Selected)',
#  'Population 18+ years (Selected)',
#  'Population 21+ years (Selected)',
#  'Population 60+ years (Selected)',
# ...

# %%
df = df.rename(columns={
    'Estimate!!Male!!Total population!!SELECTED AGE CATEGORIES!!5 to 14 years': 'Male Population 5 to 14 years (Selected)',
    'Estimate!!Male!!Total population!!SELECTED AGE CATEGORIES!!15 to 17 years': 'Male Population 15 to 17 years (Selected)',
    'Estimate!!Male!!Total population!!SELECTED AGE CATEGORIES!!Under 18 years': 'Male Population Under 18 years (Selected)',
    'Estimate!!Male!!Total population!!SELECTED AGE CATEGORIES!!18 to 24 years': 'Male Population 18 to 24 years (Selected)',
    'Estimate!!Male!!Total population!!SELECTED AGE CATEGORIES!!15 to 44 years': 'Male Population 15 to 44 years (Selected)',
    'Estimate!!Male!!Total population!!SELECTED AGE CATEGORIES!!16 years and over': 'Male Population 16+ years (Selected)',
    'Estimate!!Male!!Total population!!SELECTED AGE CATEGORIES!!18 years and over': 'Male Population 18+ years (Selected)',
    'Estimate!!Male!!Total population!!SELECTED AGE CATEGORIES!!21 years and over': 'Male Population 21+ years (Selected)',
    'Estimate!!Male!!Total population!!SELECTED AGE CATEGORIES!!60 years and over': 'Male Population 60+ years (Selected)',
    'Estimate!!Male!!Total population!!SELECTED AGE CATEGORIES!!62 years and over': 'Male Population 62+ years (Selected)',
    'Estimate!!Male!!Total population!!SELECTED AGE CATEGORIES!!65 years and over': 'Male Population 65+ years (Selected)',
    'Estimate!!Male!!Total population!!SELECTED AGE CATEGORIES!!75 years and over': 'Male Population 75+ years (Selected)',
    'Estimate!!Male!!Total population!!SUMMARY INDICATORS!!Median age (years)': 'Median Age (Male)',
    'Estimate!!Male!!Total population!!SUMMARY INDICATORS!!Sex ratio (males per 100 females)': 'Sex Ratio (Male)',
    'Estimate!!Male!!Total population!!SUMMARY INDICATORS!!Age dependency ratio': 'Age Dependency Ratio (Male)',
    'Estimate!!Male!!Total population!!SUMMARY INDICATORS!!Old-age dependency ratio': 'Old-age Dependency Ratio (Male)',
    'Estimate!!Male!!Total population!!SUMMARY INDICATORS!!Child dependency ratio': 'Child Dependency Ratio (Male)',
    'Estimate!!Male!!Total population!!PERCENT ALLOCATED!!Sex': 'Percent Allocated by Sex (Male)',
    'Estimate!!Male!!Total population!!PERCENT ALLOCATED!!Age': 'Percent Allocated by Age (Male)',
    'Estimate!!Percent Male!!Total population': 'Percent Male Population',
    'Estimate!!Percent Male!!Total population!!AGE!!Under 5 years': 'Percent Male Population Under 5 years',
    'Estimate!!Percent Male!!Total population!!AGE!!5 to 9 years': 'Percent Male Population 5 to 9 years',
    'Estimate!!Percent Male!!Total population!!AGE!!10 to 14 years': 'Percent Male Population 10 to 14 years',
    'Estimate!!Percent Male!!Total population!!AGE!!15 to 19 years': 'Percent Male Population 15 to 19 years',
    'Estimate!!Percent Male!!Total population!!AGE!!20 to 24 years': 'Percent Male Population 20 to 24 years',
    'Estimate!!Percent Male!!Total population!!AGE!!25 to 29 years': 'Percent Male Population 25 to 29 years',
    'Estimate!!Percent Male!!Total population!!AGE!!30 to 34 years': 'Percent Male Population 30 to 34 years',
    'Estimate!!Percent Male!!Total population!!AGE!!35 to 39 years': 'Percent Male Population 35 to 39 years',
    'Estimate!!Percent Male!!Total population!!AGE!!40 to 44 years': 'Percent Male Population 40 to 44 years',
    'Estimate!!Percent Male!!Total population!!AGE!!45 to 49 years': 'Percent Male Population 45 to 49 years',
    'Estimate!!Percent Male!!Total population!!AGE!!50 to 54 years': 'Percent Male Population 50 to 54 years',
    'Estimate!!Percent Male!!Total population!!AGE!!55 to 59 years': 'Percent Male Population 55 to 59 years',
    'Estimate!!Percent Male!!Total population!!AGE!!60 to 64 years': 'Percent Male Population 60 to 64 years',
    'Estimate!!Percent Male!!Total population!!AGE!!65 to 69 years': 'Percent Male Population 65 to 69 years',
    'Estimate!!Percent Male!!Total population!!AGE!!70 to 74 years': 'Percent Male Population 70 to 74 years',
    'Estimate!!Percent Male!!Total population!!AGE!!75 to 79 years': 'Percent Male Population 75 to 79 years',
    'Estimate!!Percent Male!!Total population!!AGE!!80 to 84 years': 'Percent Male Population 80 to 84 years',
    'Estimate!!Percent Male!!Total population!!AGE!!85 years and over': 'Percent Male Population 85+ years',
    'Estimate!!Percent Male!!Total population!!SELECTED AGE CATEGORIES!!5 to 14 years': 'Percent Male Population 5 to 14 years (Selected)',
    'Estimate!!Percent Male!!Total population!!SELECTED AGE CATEGORIES!!15 to 17 years': 'Percent Male Population 15 to 17 years (Selected)',
    'Estimate!!Percent Male!!Total population!!SELECTED AGE CATEGORIES!!Under 18 years': 'Percent Male Population Under 18 years (Selected)',
    'Estimate!!Percent Male!!Total population!!SELECTED AGE CATEGORIES!!18 to 24 years': 'Percent Male Population 18 to 24 years (Selected)',
    'Estimate!!Percent Male!!Total population!!SELECTED AGE CATEGORIES!!15 to 44 years': 'Percent Male Population 15 to 44 years (Selected)',
    'Estimate!!Percent Male!!Total population!!SELECTED AGE CATEGORIES!!16 years and over': 'Percent Male Population 16+ years (Selected)',
    'Estimate!!Percent Male!!Total population!!SELECTED AGE CATEGORIES!!18 years and over': 'Percent Male Population 18+ years (Selected)',
    'Estimate!!Percent Male!!Total population!!SELECTED AGE CATEGORIES!!21 years and over': 'Percent Male Population 21+ years (Selected)',
    'Estimate!!Percent Male!!Total population!!SELECTED AGE CATEGORIES!!60 years and over': 'Percent Male Population 60+ years (Selected)',
    'Estimate!!Percent Male!!Total population!!SELECTED AGE CATEGORIES!!62 years and over': 'Percent Male Population 62+ years (Selected)',
    'Estimate!!Percent Male!!Total population!!SELECTED AGE CATEGORIES!!65 years and over': 'Percent Male Population 65+ years (Selected)',
    'Estimate!!Percent Male!!Total population!!SELECTED AGE CATEGORIES!!75 years and over': 'Percent Male Population 75+ years (Selected)',
    'Estimate!!Female!!Total population!!SELECTED AGE CATEGORIES!!5 to 14 years': 'Female Population 5 to 14 years (Selected)',
    'Estimate!!Female!!Total population!!SELECTED AGE CATEGORIES!!15 to 17 years': 'Female Population 15 to 17 years (Selected)',
    'Estimate!!Female!!Total population!!SELECTED AGE CATEGORIES!!Under 18 years': 'Female Population Under 18 years (Selected)',
    'Estimate!!Female!!Total population!!SELECTED AGE CATEGORIES!!18 to 24 years': 'Female Population 18 to 24 years (Selected)',
    'Estimate!!Female!!Total population!!SELECTED AGE CATEGORIES!!15 to 44 years': 'Female Population 15 to 44 years (Selected)',
    'Estimate!!Female!!Total population!!SELECTED AGE CATEGORIES!!16 years and over': 'Female Population 16+ years (Selected)',
    'Estimate!!Female!!Total population!!SELECTED AGE CATEGORIES!!18 years and over': 'Female Population 18+ years (Selected)',
    'Estimate!!Female!!Total population!!SELECTED AGE CATEGORIES!!21 years and over': 'Female Population 21+ years (Selected)',
    'Estimate!!Female!!Total population!!SELECTED AGE CATEGORIES!!60 years and over': 'Female Population 60+ years (Selected)',
    'Estimate!!Female!!Total population!!SELECTED AGE CATEGORIES!!62 years and over': 'Female Population 62+ years (Selected)',
    'Estimate!!Female!!Total population!!SELECTED AGE CATEGORIES!!65 years and over': 'Female Population 65+ years (Selected)',
    'Estimate!!Female!!Total population!!SELECTED AGE CATEGORIES!!75 years and over': 'Female Population 75+ years (Selected)',
    'Estimate!!Female!!Total population!!SUMMARY INDICATORS!!Median age (years)': 'Median Age (Female)',
    'Estimate!!Female!!Total population!!SUMMARY INDICATORS!!Sex ratio (males per 100 females)': 'Sex Ratio (Female)',
    'Estimate!!Female!!Total population!!SUMMARY INDICATORS!!Age dependency ratio': 'Age Dependency Ratio (Female)',
    'Estimate!!Female!!Total population!!SUMMARY INDICATORS!!Old-age dependency ratio': 'Old-age Dependency Ratio (Female)',
    'Estimate!!Female!!Total population!!SUMMARY INDICATORS!!Child dependency ratio': 'Child Dependency Ratio (Female)',
    'Estimate!!Female!!Total population!!PERCENT ALLOCATED!!Sex': 'Percent Allocated by Sex (Female)',
    'Estimate!!Female!!Total population!!PERCENT ALLOCATED!!Age': 'Percent Allocated by Age (Female)',
    'Estimate!!Percent Female!!Total population': 'Percent Female Population',
    'Estimate!!Percent Female!!Total population!!AGE!!Under 5 years': 'Percent Female Population Under 5 years',
    'Estimate!!Percent Female!!Total population!!AGE!!5 to 9 years': 'Percent Female Population 5 to 9 years',
    'Estimate!!Percent Female!!Total population!!AGE!!10 to 14 years': 'Percent Female Population 10 to 14 years',
    'Estimate!!Percent Female!!Total population!!AGE!!15 to 19 years': 'Percent Female Population 15 to 19 years',
    'Estimate!!Percent Female!!Total population!!AGE!!20 to 24 years': 'Percent Female Population 20 to 24 years',
    'Estimate!!Percent Female!!Total population!!AGE!!25 to 29 years': 'Percent Female Population 25 to 29 years',
    'Estimate!!Percent Female!!Total population!!AGE!!30 to 34 years': 'Percent Female Population 30 to 34 years',
    'Estimate!!Percent Female!!Total population!!AGE!!35 to 39 years': 'Percent Female Population 35 to 39 years',
    'Estimate!!Percent Female!!Total population!!AGE!!40 to 44 years': 'Percent Female Population 40 to 44 years',
    'Estimate!!Percent Female!!Total population!!AGE!!45 to 49 years': 'Percent Female Population 45 to 49 years',
    'Estimate!!Percent Female!!Total population!!AGE!!50 to 54 years': 'Percent Female Population 50 to 54 years',
    'Estimate!!Percent Female!!Total population!!AGE!!55 to 59 years': 'Percent Female Population 55 to 59 years',
    'Estimate!!Percent Female!!Total population!!AGE!!60 to 64 years': 'Percent Female Population 60 to 64 years',
    'Estimate!!Percent Female!!Total population!!AGE!!65 to 69 years': 'Percent Female Population 65 to 69 years',
    'Estimate!!Percent Female!!Total population!!AGE!!70 to 74 years': 'Percent Female Population 70 to 74 years',
    'Estimate!!Percent Female!!Total population!!AGE!!75 to 79 years': 'Percent Female Population 75 to 79 years',
    'Estimate!!Percent Female!!Total population!!AGE!!80 to 84 years': 'Percent Female Population 80 to 84 years',
    'Estimate!!Percent Female!!Total population!!AGE!!85 years and over': 'Percent Female Population 85+ years',
    'Estimate!!Percent Female!!Total population!!SELECTED AGE CATEGORIES!!5 to 14 years': 'Percent Female Population 5 to 14 years (Selected)',
    'Estimate!!Percent Female!!Total population!!SELECTED AGE CATEGORIES!!15 to 17 years': 'Percent Female Population 15 to 17 years (Selected)',
    'Estimate!!Percent Female!!Total population!!SELECTED AGE CATEGORIES!!Under 18 years': 'Percent Female Population Under 18 years (Selected)',
    'Estimate!!Percent Female!!Total population!!SELECTED AGE CATEGORIES!!18 to 24 years': 'Percent Female Population 18 to 24 years (Selected)',
    'Estimate!!Percent Female!!Total population!!SELECTED AGE CATEGORIES!!15 to 44 years': 'Percent Female Population 15 to 44 years (Selected)',
    'Estimate!!Percent Female!!Total population!!SELECTED AGE CATEGORIES!!16 years and over': 'Percent Female Population 16+ years (Selected)',
    'Estimate!!Percent Female!!Total population!!SELECTED AGE CATEGORIES!!18 years and over': 'Percent Female Population 18+ years (Selected)',
    'Estimate!!Percent Female!!Total population!!SELECTED AGE CATEGORIES!!21 years and over': 'Percent Female Population 21+ years (Selected)',
    'Estimate!!Percent Female!!Total population!!SELECTED AGE CATEGORIES!!60 years and over': 'Percent Female Population 60+ years (Selected)',
    'Estimate!!Percent Female!!Total population!!SELECTED AGE CATEGORIES!!62 years and over': 'Percent Female Population 62+ years (Selected)',
    'Estimate!!Percent Female!!Total population!!SELECTED AGE CATEGORIES!!65 years and over': 'Percent Female Population 65+ years (Selected)',
    'Estimate!!Percent Female!!Total population!!SELECTED AGE CATEGORIES!!75 years and over': 'Percent Female Population 75+ years (Selected)',
})
list(df)
# Out:
# ['ZIP Code',
#  'Total Population',
#  'Population Under 5 years',
#  'Population 5 to 9 years',
#  'Population 10 to 14 years',
#  'Population 15 to 19 years',
#  'Population 20 to 24 years',
#  'Population 25 to 29 years',
#  'Population 30 to 34 years',
#  'Population 35 to 39 years',
#  'Population 40 to 44 years',
#  'Population 45 to 49 years',
#  'Population 50 to 54 years',
#  'Population 55 to 59 years',
#  'Population 60 to 64 years',
#  'Population 65 to 69 years',
#  'Population 70 to 74 years',
#  'Population 75 to 79 years',
#  'Population 80 to 84 years',
#  'Population 85+ years',
#  'Population 5 to 14 years (Selected)',
#  'Population 15 to 17 years (Selected)',
#  'Population Under 18 years (Selected)',
#  'Population 18 to 24 years (Selected)',
#  'Population 15 to 44 years (Selected)',
#  'Population 16+ years (Selected)',
#  'Population 18+ years (Selected)',
#  'Population 21+ years (Selected)',
#  'Population 60+ years (Selected)',
# ...

# %%
df = df.rename(columns={
    'Estimate!!Percent Male!!Total population!!SUMMARY INDICATORS!!Median age (years)': 'Median Age (Percent Male)',
    'Estimate!!Percent Male!!Total population!!SUMMARY INDICATORS!!Sex ratio (males per 100 females)': 'Sex Ratio (Percent Male)',
    'Estimate!!Percent Male!!Total population!!SUMMARY INDICATORS!!Age dependency ratio': 'Age Dependency Ratio (Percent Male)',
    'Estimate!!Percent Male!!Total population!!SUMMARY INDICATORS!!Old-age dependency ratio': 'Old-age Dependency Ratio (Percent Male)',
    'Estimate!!Percent Male!!Total population!!SUMMARY INDICATORS!!Child dependency ratio': 'Child Dependency Ratio (Percent Male)',
    'Estimate!!Percent Male!!Total population!!PERCENT ALLOCATED!!Sex': 'Percent Allocated by Sex (Percent Male)',
    'Estimate!!Percent Male!!Total population!!PERCENT ALLOCATED!!Age': 'Percent Allocated by Age (Percent Male)',
    'Estimate!!Female!!Total population': 'Female Population',
    'Estimate!!Female!!Total population!!AGE!!Under 5 years': 'Female Population Under 5 years',
    'Estimate!!Female!!Total population!!AGE!!5 to 9 years': 'Female Population 5 to 9 years',
    'Estimate!!Female!!Total population!!AGE!!10 to 14 years': 'Female Population 10 to 14 years',
    'Estimate!!Female!!Total population!!AGE!!15 to 19 years': 'Female Population 15 to 19 years',
    'Estimate!!Female!!Total population!!AGE!!20 to 24 years': 'Female Population 20 to 24 years',
    'Estimate!!Female!!Total population!!AGE!!25 to 29 years': 'Female Population 25 to 29 years',
    'Estimate!!Female!!Total population!!AGE!!30 to 34 years': 'Female Population 30 to 34 years',
    'Estimate!!Female!!Total population!!AGE!!35 to 39 years': 'Female Population 35 to 39 years',
    'Estimate!!Female!!Total population!!AGE!!40 to 44 years': 'Female Population 40 to 44 years',
    'Estimate!!Female!!Total population!!AGE!!45 to 49 years': 'Female Population 45 to 49 years',
    'Estimate!!Female!!Total population!!AGE!!50 to 54 years': 'Female Population 50 to 54 years',
    'Estimate!!Female!!Total population!!AGE!!55 to 59 years': 'Female Population 55 to 59 years',
    'Estimate!!Female!!Total population!!AGE!!60 to 64 years': 'Female Population 60 to 64 years',
    'Estimate!!Female!!Total population!!AGE!!65 to 69 years': 'Female Population 65 to 69 years',
    'Estimate!!Female!!Total population!!AGE!!70 to 74 years': 'Female Population 70 to 74 years',
    'Estimate!!Female!!Total population!!AGE!!75 to 79 years': 'Female Population 75 to 79 years',
    'Estimate!!Female!!Total population!!AGE!!80 to 84 years': 'Female Population 80 to 84 years',
    'Estimate!!Female!!Total population!!AGE!!85 years and over': 'Female Population 85+ years',
})
list(df)
# Out:
# ['ZIP Code',
#  'Total Population',
#  'Population Under 5 years',
#  'Population 5 to 9 years',
#  'Population 10 to 14 years',
#  'Population 15 to 19 years',
#  'Population 20 to 24 years',
#  'Population 25 to 29 years',
#  'Population 30 to 34 years',
#  'Population 35 to 39 years',
#  'Population 40 to 44 years',
#  'Population 45 to 49 years',
#  'Population 50 to 54 years',
#  'Population 55 to 59 years',
#  'Population 60 to 64 years',
#  'Population 65 to 69 years',
#  'Population 70 to 74 years',
#  'Population 75 to 79 years',
#  'Population 80 to 84 years',
#  'Population 85+ years',
#  'Population 5 to 14 years (Selected)',
#  'Population 15 to 17 years (Selected)',
#  'Population Under 18 years (Selected)',
#  'Population 18 to 24 years (Selected)',
#  'Population 15 to 44 years (Selected)',
#  'Population 16+ years (Selected)',
#  'Population 18+ years (Selected)',
#  'Population 21+ years (Selected)',
#  'Population 60+ years (Selected)',
# ...

# %%
df = df.rename(columns={
    'Estimate!!Percent Female!!Total population!!SUMMARY INDICATORS!!Median age (years)': 'Median Age (Percent Female)',
    'Estimate!!Percent Female!!Total population!!SUMMARY INDICATORS!!Sex ratio (males per 100 females)': 'Sex Ratio (Percent Female)',
    'Estimate!!Percent Female!!Total population!!SUMMARY INDICATORS!!Age dependency ratio': 'Age Dependency Ratio (Percent Female)',
    'Estimate!!Percent Female!!Total population!!SUMMARY INDICATORS!!Old-age dependency ratio': 'Old-age Dependency Ratio (Percent Female)',
    'Estimate!!Percent Female!!Total population!!SUMMARY INDICATORS!!Child dependency ratio': 'Child Dependency Ratio (Percent Female)',
    'Estimate!!Percent Female!!Total population!!PERCENT ALLOCATED!!Sex': 'Percent Allocated by Sex (Percent Female)',
    'Estimate!!Percent Female!!Total population!!PERCENT ALLOCATED!!Age': 'Percent Allocated by Age (Percent Female)',
})
list(df)
# Out:
# ['ZIP Code',
#  'Total Population',
#  'Population Under 5 years',
#  'Population 5 to 9 years',
#  'Population 10 to 14 years',
#  'Population 15 to 19 years',
#  'Population 20 to 24 years',
#  'Population 25 to 29 years',
#  'Population 30 to 34 years',
#  'Population 35 to 39 years',
#  'Population 40 to 44 years',
#  'Population 45 to 49 years',
#  'Population 50 to 54 years',
#  'Population 55 to 59 years',
#  'Population 60 to 64 years',
#  'Population 65 to 69 years',
#  'Population 70 to 74 years',
#  'Population 75 to 79 years',
#  'Population 80 to 84 years',
#  'Population 85+ years',
#  'Population 5 to 14 years (Selected)',
#  'Population 15 to 17 years (Selected)',
#  'Population Under 18 years (Selected)',
#  'Population 18 to 24 years (Selected)',
#  'Population 15 to 44 years (Selected)',
#  'Population 16+ years (Selected)',
#  'Population 18+ years (Selected)',
#  'Population 21+ years (Selected)',
#  'Population 60+ years (Selected)',
# ...

# %%
columns_to_drop = [
    'Population 20 to 24 years',
    'Population 25 to 29 years',
    'Population 30 to 34 years',
    'Population 35 to 39 years',
    'Population 40 to 44 years',
    'Population 45 to 49 years',
    'Population 50 to 54 years',
    'Population 55 to 59 years',
    'Population 60 to 64 years',
    'Population 65 to 69 years',
    'Population 70 to 74 years',
    'Population 75 to 79 years',
    'Population 80 to 84 years',
    'Population 85+ years',
    'Population 60+ years (Selected)',
    'Population 62+ years (Selected)',
    'Population 65+ years (Selected)',
    'Population 75+ years (Selected)',
    'Percent Population 25 to 29 years',
    'Percent Population 30 to 34 years',
    'Percent Population 35 to 39 years',
    'Percent Population 40 to 44 years',
    'Percent Population 45 to 49 years',
    'Percent Population 50 to 54 years',
    'Percent Population 55 to 59 years',
    'Percent Population 60 to 64 years',
    'Percent Population 65 to 69 years',
    'Percent Population 70 to 74 years',
    'Percent Population 75 to 79 years',
    'Percent Population 80 to 84 years',
    'Percent Population 85+ years',
    'Percent Population 21+ years (Selected)',
    'Percent Population 60+ years (Selected)',
    'Percent Population 62+ years (Selected)', 
    'Percent Population 65+ years (Selected)',
    'Percent Population 75+ years (Selected)',
    'Male Population 20 to 24 years',
    'Male Population 25 to 29 years',
    'Male Population 30 to 34 years',
    'Male Population 35 to 39 years',
    'Male Population 40 to 44 years',
    'Male Population 45 to 49 years',
    'Male Population 50 to 54 years',
    'Male Population 55 to 59 years',
    'Male Population 60 to 64 years',
    'Male Population 65 to 69 years',
    'Male Population 70 to 74 years',
    'Male Population 75 to 79 years',
    'Male Population 80 to 84 years',
    'Male Population 85+ years',
    'Male Population 21+ years (Selected)',
    'Male Population 60+ years (Selected)',
    'Male Population 62+ years (Selected)',
    'Male Population 65+ years (Selected)',
    'Male Population 75+ years (Selected)',
    'Percent Male Population 20 to 24 years',
    'Percent Male Population 25 to 29 years',
    'Percent Male Population 30 to 34 years',
    'Percent Male Population 35 to 39 years',
    'Percent Male Population 40 to 44 years',
    'Percent Male Population 45 to 49 years',
    'Percent Male Population 50 to 54 years',
    'Percent Male Population 55 to 59 years',
    'Percent Male Population 60 to 64 years',
    'Percent Male Population 65 to 69 years',
    'Percent Male Population 70 to 74 years',
    'Percent Male Population 75 to 79 years',
    'Percent Male Population 80 to 84 years',
    'Percent Male Population 85+ years',
    'Percent Female Population 20 to 24 years',
    'Percent Female Population 25 to 29 years',
    'Percent Female Population 30 to 34 years',
    'Percent Female Population 35 to 39 years',
    'Percent Female Population 40 to 44 years',
    'Percent Female Population 45 to 49 years',
    'Percent Female Population 50 to 54 years',
    'Percent Female Population 55 to 59 years',
    'Percent Female Population 60 to 64 years',
    'Percent Female Population 65 to 69 years',
    'Percent Female Population 70 to 74 years',
    'Percent Female Population 75 to 79 years',
    'Percent Female Population 80 to 84 years',
    'Percent Female Population 85+ years',
    'Percent Female Population 21+ years (Selected)',
    'Percent Female Population 60+ years (Selected)',
    'Percent Female Population 62+ years (Selected)',
    'Percent Female Population 65+ years (Selected)',
    'Percent Female Population 75+ years (Selected)',
]

df = df.drop(columns=columns_to_drop)

list(df)
# Out:
# ['ZIP Code',
#  'Total Population',
#  'Population Under 5 years',
#  'Population 5 to 9 years',
#  'Population 10 to 14 years',
#  'Population 15 to 19 years',
#  'Population 5 to 14 years (Selected)',
#  'Population 15 to 17 years (Selected)',
#  'Population Under 18 years (Selected)',
#  'Population 18 to 24 years (Selected)',
#  'Population 15 to 44 years (Selected)',
#  'Population 16+ years (Selected)',
#  'Population 18+ years (Selected)',
#  'Population 21+ years (Selected)',
#  'Median Age (Total)',
#  'Sex Ratio (Total)',
#  'Age Dependency Ratio (Total)',
#  'Old-age Dependency Ratio (Total)',
#  'Child Dependency Ratio (Total)',
#  'Percent Allocated by Sex',
#  'Percent Allocated by Age',
#  'Percent Total Population',
#  'Percent Population Under 5 years',
#  'Percent Population 5 to 9 years',
#  'Percent Population 10 to 14 years',
#  'Percent Population 15 to 19 years',
#  'Percent Population 20 to 24 years',
#  'Percent Population 5 to 14 years (Selected)',
# ...

# %%
columns_to_drop = [
    'Percent Male Population 21+ years (Selected)',
    'Percent Male Population 60+ years (Selected)',
    'Percent Male Population 62+ years (Selected)',
    'Percent Male Population 65+ years (Selected)',
    'Percent Male Population 75+ years (Selected)',
    'Population 21+ years (Selected)',
    'Female Population 20 to 24 years',
    'Female Population 25 to 29 years',
    'Female Population 30 to 34 years',
    'Female Population 35 to 39 years',
    'Female Population 40 to 44 years',
    'Female Population 45 to 49 years',
    'Female Population 50 to 54 years',
    'Female Population 55 to 59 years',
    'Female Population 60 to 64 years',
    'Female Population 65 to 69 years',
    'Female Population 70 to 74 years',
    'Female Population 75 to 79 years',
    'Female Population 80 to 84 years',
    'Female Population 85+ years',
    'Female Population 60+ years (Selected)',
    'Female Population 62+ years (Selected)',
    'Female Population 65+ years (Selected)',
    'Female Population 75+ years (Selected)',
]
df = df.drop(columns=columns_to_drop)

list(df)
# Out:
# ['ZIP Code',
#  'Total Population',
#  'Population Under 5 years',
#  'Population 5 to 9 years',
#  'Population 10 to 14 years',
#  'Population 15 to 19 years',
#  'Population 5 to 14 years (Selected)',
#  'Population 15 to 17 years (Selected)',
#  'Population Under 18 years (Selected)',
#  'Population 18 to 24 years (Selected)',
#  'Population 15 to 44 years (Selected)',
#  'Population 16+ years (Selected)',
#  'Population 18+ years (Selected)',
#  'Median Age (Total)',
#  'Sex Ratio (Total)',
#  'Age Dependency Ratio (Total)',
#  'Old-age Dependency Ratio (Total)',
#  'Child Dependency Ratio (Total)',
#  'Percent Allocated by Sex',
#  'Percent Allocated by Age',
#  'Percent Total Population',
#  'Percent Population Under 5 years',
#  'Percent Population 5 to 9 years',
#  'Percent Population 10 to 14 years',
#  'Percent Population 15 to 19 years',
#  'Percent Population 20 to 24 years',
#  'Percent Population 5 to 14 years (Selected)',
# ...

# %%
df.head()
# Out:
# 0  ZIP Code Total Population Population Under 5 years Population 5 to 9 years  \
# 1     89010              461                       20                      28
# 2     89019             2312                       56                      31
# 3     89060            12198                      509                     662
# 4     89061             7529                       69                     411
# 5     89439             1639                       42                     111
#
# 0 Population 10 to 14 years Population 15 to 19 years  \
# 1                        23                        10
# 2                        28                        76
# 3                       372                       510
# 4                       342                       184
# 5                        29                        18
#
# 0 Population 5 to 14 years (Selected) Population 15 to 17 years (Selected)  \
# 1                                  51                                    0
# ...

# %%
columns_to_keep = [
    'ZIP Code',
    'Total Population',
    'Population Under 5 years',
    'Population 5 to 9 years',
    'Population 10 to 14 years',
    'Population 15 to 19 years',
    'Population Under 18 years (Selected)',
    'Percent Population Under 5 years',
    'Percent Population 5 to 9 years',
    'Percent Population 10 to 14 years',
    'Percent Population Under 18 years (Selected)',
    'Male Population Under 5 years',
    'Male Population 5 to 9 years',
    'Male Population 10 to 14 years',
    'Female Population Under 5 years',
    'Female Population 5 to 9 years',
    'Female Population 10 to 14 years',
    'Female Population Under 18 years (Selected)'
]
df_children = df[columns_to_keep]

df_children.head()
# Out:
# 0  ZIP Code Total Population Population Under 5 years Population 5 to 9 years  \
# 1     89010              461                       20                      28
# 2     89019             2312                       56                      31
# 3     89060            12198                      509                     662
# 4     89061             7529                       69                     411
# 5     89439             1639                       42                     111
#
# 0 Population 10 to 14 years Population 15 to 19 years  \
# 1                        23                        10
# 2                        28                        76
# 3                       372                       510
# 4                       342                       184
# 5                        29                        18
#
# 0 Population Under 18 years (Selected) Percent Population Under 5 years  \
# 1                                   71                              4.3
# ...

# %%
columns_order = ['ZIP Code', 
                 'Population Under 18 years (Selected)',
                 'Total Population',
                 'Population Under 5 years',
                 'Population 5 to 9 years',
                 'Population 10 to 14 years',
                 'Population 15 to 19 years',
                 'Percent Population Under 5 years',
                 'Percent Population 5 to 9 years',
                 'Percent Population 10 to 14 years',
                 'Percent Population Under 18 years (Selected)',
                 'Male Population Under 5 years',
                 'Male Population 5 to 9 years',
                 'Male Population 10 to 14 years',
                 'Female Population Under 5 years',
                 'Female Population 5 to 9 years',
                 'Female Population 10 to 14 years',
                 'Female Population Under 18 years (Selected)']

df_children = df_children[columns_order]

df_children.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1808 entries, 1 to 1808
# Data columns (total 18 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   ZIP Code                                      1808 non-null   int64
#  1   Population Under 18 years (Selected)          1808 non-null   object
#  2   Total Population                              1808 non-null   object
#  3   Population Under 5 years                      1808 non-null   object
#  4   Population 5 to 9 years                       1808 non-null   object
#  5   Population 10 to 14 years                     1808 non-null   object
#  6   Population 15 to 19 years                     1808 non-null   object
#  7   Percent Population Under 5 years              1808 non-null   object
#  8   Percent Population 5 to 9 years               1808 non-null   object
# ...

# %%
columns_to_convert = [
    'Population Under 18 years (Selected)',
    'Total Population',
    'Population Under 5 years',
    'Population 5 to 9 years',
    'Population 10 to 14 years',
    'Population 15 to 19 years',
    'Percent Population Under 5 years',
    'Percent Population 5 to 9 years',
    'Percent Population 10 to 14 years',
    'Percent Population Under 18 years (Selected)',
    'Male Population Under 5 years',
    'Male Population 5 to 9 years',
    'Male Population 10 to 14 years',
    'Female Population Under 5 years',
    'Female Population 5 to 9 years',
    'Female Population 10 to 14 years',
    'Female Population Under 18 years (Selected)'
]

df_children[columns_to_convert] = df_children[columns_to_convert].apply(pd.to_numeric, errors='coerce')

df_children.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1808 entries, 1 to 1808
# Data columns (total 18 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   ZIP Code                                      1808 non-null   int64
#  1   Population Under 18 years (Selected)          1808 non-null   int64
#  2   Total Population                              1808 non-null   int64
#  3   Population Under 5 years                      1808 non-null   int64
#  4   Population 5 to 9 years                       1808 non-null   int64
#  5   Population 10 to 14 years                     1808 non-null   int64
#  6   Population 15 to 19 years                     1808 non-null   int64
#  7   Percent Population Under 5 years              1771 non-null   float64
#  8   Percent Population 5 to 9 years               1771 non-null   float64
# ...

# %%
df_children.head()
# Out:
# 0  ZIP Code  Population Under 18 years (Selected)  Total Population  \
# 1     89010                                    71               461
# 2     89019                                   146              2312
# 3     89060                                  1917             12198
# 4     89061                                   971              7529
# 5     89439                                   192              1639
#
# 0  Population Under 5 years  Population 5 to 9 years  \
# 1                        20                       28
# 2                        56                       31
# 3                       509                      662
# 4                        69                      411
# 5                        42                      111
#
# 0  Population 10 to 14 years  Population 15 to 19 years  \
# 1                         23                         10
# 2                         28                         76
# 3                        372                        510
# ...

# %%
duplicates = df_children.duplicated()

df_children[duplicates]
# Out:
# Empty DataFrame
# Columns: [ZIP Code, Population Under 18 years (Selected), Total Population, Population Under 5 years, Population 5 to 9 years, Population 10 to 14 years, Population 15 to 19 years, Percent Population Under 5 years, Percent Population 5 to 9 years, Percent Population 10 to 14 years, Percent Population Under 18 years (Selected), Male Population Under 5 years, Male Population 5 to 9 years, Male Population 10 to 14 years, Female Population Under 5 years, Female Population 5 to 9 years, Female Population 10 to 14 years, Female Population Under 18 years (Selected)]
# Index: []
